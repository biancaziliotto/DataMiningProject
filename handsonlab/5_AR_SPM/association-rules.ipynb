# %% [markdown]
# # Apriori algorithm

# %% [markdown]
# #### we used the FIM package. You can find it here for Ananconda installation https://anaconda.org/conda-forge/pyfim.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fim import apriori

# %% [markdown]
# #### Pattern mining on relational data

# %%
dataset = pd.read_csv("./datasets/small_transactions.csv", skipinitialspace=True, sep=',', nrows=2000)
dataset.head()
# Out:
#     SCONTRINO_ID  COD_MKT_ID
# 0  2558064013053        1580
# 1  2558064013053        1661
# 2  2558064013053        2068
# 3  2558064013053        2556
# 4  2558064013053        2650

# %% [markdown]
# ##### This is a relational representation: each row of the dataframe has a basket ID and one product bought. For our analysis, we need the transactions: the list of product bought for each basket.

# %%
transactions = dataset.groupby('SCONTRINO_ID')['COD_MKT_ID'].apply(list)
transactions.head()
# Out:
# SCONTRINO_ID
# 2558064013053                 [1580, 1661, 2068, 2556, 2650, 4225]
# 2558064013054    [437, 1278, 1614, 2089, 2243, 2245, 2443, 2551...
# 2558064013055                         [151, 595, 2650, 4600, 4872]
# 2558064013056             [142, 437, 2499, 2515, 3458, 3675, 4044]
# 2558064013057                                          [437, 3087]
# Name: COD_MKT_ID, dtype: object

# %%
baskets = transactions.values

# %%
baskets[0:5]
# Out:
# array([list([1580, 1661, 2068, 2556, 2650, 4225]),
#        list([437, 1278, 1614, 2089, 2243, 2245, 2443, 2551, 3448, 6172]),
#        list([151, 595, 2650, 4600, 4872]),
#        list([142, 437, 2499, 2515, 3458, 3675, 4044]), list([437, 3087])],
#       dtype=object)

# %% [markdown]
# #### We can now run the apriori algorithm, implemented in fim. To know the options available:

# %%
help(apriori)
# Out:
# Help on built-in function apriori in module fim:
#
# apriori(...)
#     apriori (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#              eval='x', agg='x', thresh=10, prune=None, algo='b', mode='',
#              border=None)
#     Find frequent item sets with the Apriori algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
#             r     rules      association rules
#     supp    minimum support of an item set         (default: 10)
#             (positive: percentage, negative: absolute number)
#     conf    minimum confidence of an assoc. rule   (default: 80%)
#     zmin    minimum number of items per item set   (default: 1)
#     zmax    maximum number of items per item set   (default: no limit)
#     report  values to report with an item set      (default: a)
#             a     absolute item set support (number of transactions)
#             s     relative item set support as a fraction
#             S     relative item set support as a percentage
#             e     value of item set evaluation measure
#             E     value of item set evaluation measure as a percentage
#             (     combine values in a tuple (must be first character)
#             [     combine values in a list  (must be first character)
#             #     pattern spectrum as a dictionary  (no patterns)
#             =     pattern spectrum as a list        (no patterns)
#             |     pattern spectrum as three columns (no patterns)
#             for target 'r' (association rules) also available:
#             b     absolute body set  support (number of transactions)
#             x     relative body set  support as a fraction
#             X     relative body set  support as a percentage
#             h     absolute head item support (number of transactions)
#             y     relative head item support as a fraction
#             Y     relative head item support as a percentage
#             c     rule confidence as a fraction
#             C     rule confidence as a percentage
#             l     lift value of a rule (confidence/prior)
#             L     lift value of a rule as a percentage
#             Q     support of the empty set (total number of transactions)
#     eval    measure for item set evaluation        (default: x)
#             x     none       no measure / zero (default)
#             b     ldratio    binary logarithm of support quotient       (+)
#             c     conf       rule confidence                            (+)
#             d     confdiff   absolute confidence difference to prior    (+)
#             l     lift       lift value (confidence divided by prior)   (+)
#             a     liftdiff   absolute difference of lift value to 1     (+)
#             q     liftquot   difference of lift quotient to 1           (+)
#             v     cvct       conviction (inverse lift negated head)     (+)
#             e     cvctdiff   absolute difference of conviction to 1     (+)
#             r     cvctquot   difference of conviction quotient to 1     (+)
#             b     imbal      imbalance ratio                            (+)
#             k     kulc       Kulczynski measure                         (+)
#             w     kulcdiff   difference of Kulczynski measure to 0.5    (+)
#             u     cprob      conditional probability ratio              (+)
#             j     import     importance (binary log. of prob. ratio)    (+)
#             z     cert       certainty factor (relative conf. change)   (+)
#             n     chi2       normalized chi^2 measure                   (+)
#             p     chi2pval   p-value f/ (unnormalized) chi^2 measure    (-)
#             y     yates      normalized chi^2 with Yates' correction    (+)
#             t     yatespval  p-value f/ Yates-corrected chi^2 measure   (-)
#             i     info       information difference to prior            (+)
#             g     infopval   p-value f/ G statistic/info. difference    (-)
#             f     fetprob    Fisher's exact test (table probability)    (-)
#             h     fetchi2    Fisher's exact test (chi^2 measure)        (-)
#             m     fetinfo    Fisher's exact test (mutual information)   (-)
#             s     fetsupp    Fisher's exact test (support)              (-)
#             Measures marked with (+) must meet or exceed the threshold,
#             measures marked with (-) must not exceed the threshold
#             in order for the item set to be reported.
#     agg     evaluation measure aggregation mode    (default: x)
#             x     none       no aggregation (use first value)
#             m     min        minimum of individual measure values
#             n     max        maximum of individual measure values
#             a     avg        average of individual measure values
#     thresh  threshold for evaluation measure       (default: 10%)
#     prune   min. size for evaluation filtering     (default: no pruning)
#             = 0   backward filtering       (no subset check)
#             < 0   weak   forward filtering (one subset  must qualify)
#             > 0   strong forward filtering (all subsets must qualify)
#     algo    algorithm variant to use               (default: a)
#             b     basic      standard algorithm (only choice)
#     mode    operation mode indicators/flags        (default: None)
#             x     do not use perfect extension pruning
#             t/T   do not organize transactions as a prefix tree
#             y     a-posteriori pruning of infrequent item sets
#             z     invalidate evaluation below expected support
#             o     use original rule support definition (body & head)
#     border  support border for filtering item sets (default: None)
#             Must be a list or tuple of (absolute) minimum support values
#             per item set size (by which the list/tuple is indexed).
#     appear  dictionary mapping items to item appearance indicators,
#             with the key None referring to the default item appearance.
#             (If None does not occur as a key or no dictionary is given,
#             the default item appearance indicator is 'both'.)
#             This parameter is only used if the target type is rules.
#             * item may not appear anywhere in a rule:
#               '-', 'n', 'none', 'neither', 'ignore'
#             * item may appear only in rule body/antecedent:
#               'i', 'in', 'inp', 'input', 'b', 'body',
#               'a', 'ante', 'antecedent'
#             * item may appear only in rule head/consequent:
#               'o', 'out',      'output', 'h', 'head',
#               'c', 'cons', 'consequent'
#             * item may appear anywhere in a rule:
#               'io', 'i&o', 'inout', 'in&out', 'bh', 'b&h', 'both'
#     returns if report is not in ['#','=','|']:
#               if the target is association rules:
#                 a list of rules (i.e. tuples with two or more elements),
#                 each consisting of a head/consequent item, a tuple with
#                 a body/antecedent item set, and the values selected by
#                 the parameter 'report', which may be combined into a
#                 tuple or a list if report[0] is '(' or '[', respectively.
#               if the target is a type of item sets:
#                 a list of patterns (i.e. tuples with one or more elements),
#                 each consisting of a tuple with a found frequent item set
#                 and the values selected by the parameter 'report', which
#                 may be combined into a tuple or list if report[0] is '('
#                 or '[', respectively
#             if report in ['#','=','|']:
#               a pattern spectrum as a dictionary mapping pattern sizes
#               to the corresponding occurrence support ranges, as a list
#               of triplets (size, min. support, max. support) or as three
#               columns for sizes and minimum and maximum support values

# %%
# An itemset is maximal frequent if none of its immediate supersets is frequent. 
# An itemset is closed if none of its immediate supersets has the same support as the itemset .

# %% [markdown]
# #### First, we want to extract the itemsets: we do it setting target=a

# %%
itemsets = apriori(baskets, supp=1, zmin=2, zmax=5, target='a', eval='s')

# %%
# frequent itemset, support
itemsets
# Out:
# [((3086, 2443), 3),
#  ((441, 2050), 3),
#  ((441, 2650), 3),
#  ((1278, 2243), 4),
#  ((4805, 437), 3),
#  ((396, 2650), 3),
#  ((476, 2650), 3),
#  ((4163, 2650), 3),
#  ((2498, 920), 3),
#  ((385, 2729), 3),
#  ((2490, 923), 3),
#  ((2490, 2650), 3),
#  ((1094, 3750), 3),
#  ((1094, 2243), 3),
#  ((1094, 445), 3),
#  ((1094, 2650), 3),
#  ((4182, 445), 3),
#  ((4182, 445, 2650), 3),
#  ((4182, 2650), 3),
#  ((624, 597), 3),
#  ((4461, 920), 3),
#  ((142, 393), 3),
#  ((1258, 2650), 3),
#  ((2518, 2499), 3),
#  ((2518, 920), 3),
#  ((599, 597), 3),
#  ((2550, 2650), 3),
#  ((4136, 6172), 3),
#  ((3074, 437), 3),
#  ((1658, 445), 4),
#  ((1658, 445, 2650), 3),
#  ((1658, 2650), 3),
#  ((1429, 1428), 4),
#  ((207, 2650), 3),
#  ((563, 2194), 3),
#  ((4600, 3739), 3),
#  ((5087, 445), 3),
#  ((5087, 445, 2650), 3),
#  ((5087, 920), 3),
#  ((5087, 2650), 4),
#  ((4047, 2729), 3),
#  ((4047, 2650), 4),
#  ((621, 4801), 3),
#  ((621, 1579), 3),
#  ((1101, 437), 4),
#  ((2556, 1580), 3),
#  ((2556, 445), 3),
#  ((2556, 920), 3),
#  ((2556, 2650), 3),
#  ((2181, 3000442), 3),
#  ((2245, 3087), 3),
#  ((3451, 445), 3),
#  ((4228, 1661), 3),
#  ((4228, 2762), 3),
#  ((4228, 2650), 4),
#  ((480, 437), 3),
#  ((447, 2089), 3),
#  ((447, 920), 3),
#  ((1423, 3087), 3),
#  ((1423, 3087, 445), 3),
#  ((1423, 445), 3),
#  ((1423, 2650), 3),
#  ((4665, 2650), 3),
#  ((2445, 1579), 3),
#  ((2532, 3672), 3),
#  ((2532, 3672, 3087), 3),
#  ((2532, 3087), 3),
#  ((2532, 920), 3),
#  ((5086, 3087), 3),
#  ((2530, 2058), 3),
#  ((2530, 2193), 3),
#  ((2530, 920), 3),
#  ((2530, 2650), 3),
#  ((614, 2074), 3),
#  ((143, 2650), 3),
#  ((2109, 2065), 3),
#  ((2109, 920), 3),
#  ((2109, 2650), 3),
#  ((622, 3087), 4),
#  ((622, 445), 4),
#  ((622, 445, 2650), 3),
#  ((622, 2650), 3),
#  ((4332, 445), 3),
#  ((2085, 4044), 3),
#  ((2085, 4044, 920), 3),
#  ((2085, 2089), 3),
#  ((2085, 445), 3),
#  ((2085, 445, 920), 3),
#  ((2085, 920), 4),
#  ((3000401, 140), 3),
#  ((3458, 2057), 3),
#  ((3458, 3448), 3),
#  ((3458, 2650), 3),
#  ((2194, 923), 3),
#  ((2194, 2052), 3),
#  ((2194, 920), 4),
#  ((2194, 2650), 4),
#  ((3686, 2727), 3),
#  ((3686, 1579), 3),
#  ((3686, 920), 3),
#  ((2058, 2729), 4),
#  ((2058, 445), 3),
#  ((2058, 920), 3),
#  ((2058, 2650), 4),
#  ((1614, 437), 3),
#  ((1614, 2762), 4),
#  ((1614, 2762, 2650), 3),
#  ((1614, 3087), 3),
#  ((1614, 6172), 4),
#  ((1614, 2650), 5),
#  ((644, 437), 3),
#  ((644, 6172), 4),
#  ((644, 6172, 2650), 3),
#  ((644, 920), 3),
#  ((644, 2650), 4),
#  ((560, 1579), 3),
#  ((560, 3087), 3),
#  ((560, 445), 4),
#  ((2057, 4044), 3),
#  ((2057, 437), 4),
#  ((2057, 6172), 3),
#  ((2057, 920), 5),
#  ((2057, 920, 2650), 3),
#  ((2057, 2650), 5),
#  ((446, 3664), 3),
#  ((446, 2729), 3),
#  ((446, 445), 3),
#  ((446, 445, 2650), 3),
#  ((446, 6172), 4),
#  ((446, 920), 3),
#  ((446, 2650), 4),
#  ((1661, 4003), 4),
#  ((1661, 4003, 445), 3),
#  ((1661, 4003, 2650), 3),
#  ((1661, 445), 4),
#  ((1661, 445, 2650), 3),
#  ((1661, 920), 3),
#  ((1661, 920, 2650), 3),
#  ((1661, 2650), 7),
#  ((2727, 3000442), 3),
#  ((2727, 3000442, 2762), 3),
#  ((2727, 2762), 3),
#  ((2727, 2729), 4),
#  ((2727, 3087), 3),
#  ((1090, 2050), 3),
#  ((3672, 2065), 3),
#  ((3672, 2089), 3),
#  ((3672, 2089, 920), 3),
#  ((3672, 2729), 3),
#  ((3672, 3087), 3),
#  ((3672, 920), 3),
#  ((2551, 5072), 3),
#  ((2551, 6172), 3),
#  ((2551, 920), 4),
#  ((923, 2499), 3),
#  ((923, 2499, 920), 3),
#  ((923, 2443), 4),
#  ((923, 1579), 3),
#  ((923, 920), 5),
#  ((923, 2650), 4),
#  ((3750, 4003), 3),
#  ((3750, 4003, 445), 3),
#  ((3750, 2729), 3),
#  ((3750, 445), 7),
#  ((3750, 445, 920), 4),
#  ((3750, 6172), 4),
#  ((3750, 920), 4),
#  ((3750, 2650), 4),
#  ((2052, 3448), 3),
#  ((2052, 3087), 3),
#  ((2052, 445), 4),
#  ((2052, 2650), 4),
#  ((1580, 140), 3),
#  ((1580, 2065), 3),
#  ((1580, 2762), 3),
#  ((1580, 1579), 3),
#  ((1580, 445), 3),
#  ((1580, 6172), 3),
#  ((1580, 2650), 3),
#  ((1428, 2650), 3),
#  ((4655, 2499), 3),
#  ((4655, 2499, 920), 3),
#  ((4655, 2443), 3),
#  ((4655, 920), 3),
#  ((3664, 2193), 3),
#  ((3664, 6172), 4),
#  ((3664, 920), 3),
#  ((4106, 4044), 3),
#  ((4106, 4044, 2729), 3),
#  ((4106, 1579), 3),
#  ((4106, 2729), 4),
#  ((4106, 920), 3),
#  ((2050, 559), 3),
#  ((2050, 559, 6172), 3),
#  ((2050, 445), 3),
#  ((2050, 6172), 4),
#  ((2050, 920), 3),
#  ((2050, 2650), 7),
#  ((3000442, 2443), 3),
#  ((3000442, 2762), 5),
#  ((3000442, 2762, 3087), 4),
#  ((3000442, 3087), 5),
#  ((1425, 4003), 3),
#  ((1425, 6172), 3),
#  ((1425, 920), 3),
#  ((1425, 2650), 4),
#  ((2242, 140), 3),
#  ((2242, 1579), 5),
#  ((2242, 3087), 3),
#  ((2242, 2650), 4),
#  ((4623, 3087), 3),
#  ((3739, 2495), 3),
#  ((3739, 4003), 3),
#  ((3739, 2762), 3),
#  ((2193, 2243), 3),
#  ((2193, 2243, 445), 3),
#  ((2193, 2499), 3),
#  ((2193, 2499, 2089), 3),
#  ((2193, 2499, 2089, 920), 3),
#  ((2193, 2499, 920), 3),
#  ((2193, 2089), 4),
#  ((2193, 2089, 1579), 3),
#  ((2193, 2089, 3087), 3),
#  ((2193, 2089, 920), 3),
#  ((2193, 1579), 3),
#  ((2193, 3087), 3),
#  ((2193, 445), 5),
#  ((2193, 445, 920), 4),
#  ((2193, 920), 7),
#  ((4658, 2499), 3),
#  ((4658, 3448), 4),
#  ((4658, 3448, 2443), 3),
#  ((4658, 3448, 445), 3),
#  ((4658, 3448, 445, 920), 3),
#  ((4658, 3448, 920), 3),
#  ((4658, 2443), 5),
#  ((4658, 2443, 445), 3),
#  ((4658, 2443, 445, 920), 3),
#  ((4658, 2443, 920), 3),
#  ((4658, 2762), 3),
#  ((4658, 2729), 3),
#  ((4658, 2729, 2650), 3),
#  ((4658, 445), 6),
#  ((4658, 445, 920), 5),
#  ((4658, 920), 7),
#  ((4658, 2650), 3),
#  ((2074, 2065), 3),
#  ((2074, 2762), 3),
#  ((2074, 1579), 3),
#  ((2074, 1579, 3087), 3),
#  ((2074, 3087), 4),
#  ((2074, 2650), 3),
#  ((5072, 2495), 3),
#  ((5072, 4044), 3),
#  ((5072, 2443), 3),
#  ((5072, 1579), 3),
#  ((5072, 1579, 3087), 3),
#  ((5072, 2729), 3),
#  ((5072, 2729, 920), 3),
#  ((5072, 3087), 4),
#  ((5072, 445), 5),
#  ((5072, 920), 4),
#  ((5072, 2650), 3),
#  ((2243, 437), 3),
#  ((2243, 3087), 5),
#  ((2243, 3087, 445), 4),
#  ((2243, 445), 7),
#  ((2243, 445, 6172), 3),
#  ((2243, 445, 2650), 3),
#  ((2243, 6172), 4),
#  ((2243, 920), 4),
#  ((2243, 2650), 6),
#  ((2499, 2089), 3),
#  ((2499, 2089, 920), 3),
#  ((2499, 2443), 3),
#  ((2499, 2443, 920), 3),
#  ((2499, 1579), 3),
#  ((2499, 1579, 920), 3),
#  ((2499, 2729), 3),
#  ((2499, 2729, 920), 3),
#  ((2499, 3087), 3),
#  ((2499, 3087, 920), 3),
#  ((2499, 445), 4),
#  ((2499, 445, 920), 4),
#  ((2499, 920), 8),
#  ((140, 1579), 3),
#  ((140, 445), 4),
#  ((140, 6172), 4),
#  ((140, 2650), 4),
#  ((559, 252), 3),
#  ((559, 6172), 5),
#  ((559, 6172, 2650), 3),
#  ((559, 2650), 4),
#  ((3448, 2495), 4),
#  ((3448, 2443), 5),
#  ((3448, 1579), 4),
#  ((3448, 3087), 3),
#  ((3448, 445), 6),
#  ((3448, 445, 920), 5),
#  ((3448, 920), 7),
#  ((2495, 4044), 4),
#  ((2495, 4044, 920), 3),
#  ((2495, 1579), 4),
#  ((2495, 1579, 3087), 3),
#  ((2495, 2729), 3),
#  ((2495, 3087), 5),
#  ((2495, 445), 3),
#  ((2495, 6172), 3),
#  ((2495, 920), 4),
#  ((252, 4044), 3),
#  ((252, 4044, 1579), 3),
#  ((252, 1579), 4),
#  ((252, 3087), 3),
#  ((252, 2650), 3),
#  ((4003, 2729), 5),
#  ((4003, 445), 6),
#  ((4003, 445, 920), 3),
#  ((4003, 445, 2650), 3),
#  ((4003, 6172), 3),
#  ((4003, 920), 4),
#  ((4003, 2650), 4),
#  ((4044, 2443), 3),
#  ((4044, 2443, 920), 3),
#  ((4044, 1579), 4),
#  ((4044, 2729), 3),
#  ((4044, 445), 3),
#  ((4044, 445, 920), 3),
#  ((4044, 920), 6),
#  ((4044, 2650), 3),
#  ((2065, 3087), 3),
#  ((2065, 445), 3),
#  ((2065, 920), 3),
#  ((2065, 2650), 5),
#  ((2089, 2443), 4),
#  ((2089, 2443, 437), 3),
#  ((2089, 2443, 920), 3),
#  ((2089, 437), 5),
#  ((2089, 437, 2650), 3),
#  ((2089, 1579), 4),
#  ((2089, 2729), 3),
#  ((2089, 3087), 4),
#  ((2089, 6172), 4),
#  ((2089, 920), 6),
#  ((2089, 2650), 3),
#  ((2443, 437), 4),
#  ((2443, 2762), 4),
#  ((2443, 1579), 3),
#  ((2443, 3087), 3),
#  ((2443, 445), 5),
#  ((2443, 445, 920), 3),
#  ((2443, 6172), 3),
#  ((2443, 920), 8),
#  ((2443, 2650), 5),
#  ((437, 1579), 3),
#  ((437, 3087), 5),
#  ((437, 6172), 5),
#  ((437, 920), 4),
#  ((437, 2650), 6),
#  ((2762, 2729), 4),
#  ((2762, 3087), 7),
#  ((2762, 3087, 2650), 3),
#  ((2762, 445), 3),
#  ((2762, 445, 2650), 3),
#  ((2762, 6172), 5),
#  ((2762, 6172, 2650), 3),
#  ((2762, 2650), 7),
#  ((1579, 2729), 5),
#  ((1579, 2729, 920), 3),
#  ((1579, 3087), 6),
#  ((1579, 445), 3),
#  ((1579, 445, 920), 3),
#  ((1579, 920), 5),
#  ((2729, 3087), 4),
#  ((2729, 445), 5),
#  ((2729, 445, 920), 4),
#  ((2729, 445, 2650), 3),
#  ((2729, 6172), 8),
#  ((2729, 920), 9),
#  ((2729, 920, 2650), 3),
#  ((2729, 2650), 7),
#  ((3087, 445), 7),
#  ((3087, 445, 2650), 3),
#  ((3087, 6172), 3),
#  ((3087, 920), 5),
#  ((3087, 2650), 9),
#  ((445, 6172), 7),
#  ((445, 6172, 2650), 3),
#  ((445, 920), 15),
#  ((445, 2650), 16),
#  ((6172, 920), 6),
#  ((6172, 2650), 13),
#  ((920, 2650), 9)]

# %% [markdown]
# #### We can now see the itemsets obtained and their support

# %%
print('Number of itemsets:', len(itemsets))
# Out:
# Number of itemsets: 392

# %%
itemsets[20:35]
# Out:
# [((4461, 920), 3),
#  ((142, 393), 3),
#  ((1258, 2650), 3),
#  ((2518, 2499), 3),
#  ((2518, 920), 3),
#  ((599, 597), 3),
#  ((2550, 2650), 3),
#  ((4136, 6172), 3),
#  ((3074, 437), 3),
#  ((1658, 445), 4),
#  ((1658, 445, 2650), 3),
#  ((1658, 2650), 3),
#  ((1429, 1428), 4),
#  ((207, 2650), 3),
#  ((563, 2194), 3)]

# %% [markdown]
# ### Rules

# %% [markdown]
# #### With apriori we can also extract the rules, by setting target=r. Remeber that in this case we need to set a support value as well as a confidence one

# %%
help(apriori)
# Out:
# Help on built-in function apriori in module fim:
#
# apriori(...)
#     apriori (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#              eval='x', agg='x', thresh=10, prune=None, algo='b', mode='',
#              border=None)
#     Find frequent item sets with the Apriori algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
#             r     rules      association rules
#     supp    minimum support of an item set         (default: 10)
#             (positive: percentage, negative: absolute number)
#     conf    minimum confidence of an assoc. rule   (default: 80%)
#     zmin    minimum number of items per item set   (default: 1)
#     zmax    maximum number of items per item set   (default: no limit)
#     report  values to report with an item set      (default: a)
#             a     absolute item set support (number of transactions)
#             s     relative item set support as a fraction
#             S     relative item set support as a percentage
#             e     value of item set evaluation measure
#             E     value of item set evaluation measure as a percentage
#             (     combine values in a tuple (must be first character)
#             [     combine values in a list  (must be first character)
#             #     pattern spectrum as a dictionary  (no patterns)
#             =     pattern spectrum as a list        (no patterns)
#             |     pattern spectrum as three columns (no patterns)
#             for target 'r' (association rules) also available:
#             b     absolute body set  support (number of transactions)
#             x     relative body set  support as a fraction
#             X     relative body set  support as a percentage
#             h     absolute head item support (number of transactions)
#             y     relative head item support as a fraction
#             Y     relative head item support as a percentage
#             c     rule confidence as a fraction
#             C     rule confidence as a percentage
#             l     lift value of a rule (confidence/prior)
#             L     lift value of a rule as a percentage
#             Q     support of the empty set (total number of transactions)
#     eval    measure for item set evaluation        (default: x)
#             x     none       no measure / zero (default)
#             b     ldratio    binary logarithm of support quotient       (+)
#             c     conf       rule confidence                            (+)
#             d     confdiff   absolute confidence difference to prior    (+)
#             l     lift       lift value (confidence divided by prior)   (+)
#             a     liftdiff   absolute difference of lift value to 1     (+)
#             q     liftquot   difference of lift quotient to 1           (+)
#             v     cvct       conviction (inverse lift negated head)     (+)
#             e     cvctdiff   absolute difference of conviction to 1     (+)
#             r     cvctquot   difference of conviction quotient to 1     (+)
#             b     imbal      imbalance ratio                            (+)
#             k     kulc       Kulczynski measure                         (+)
#             w     kulcdiff   difference of Kulczynski measure to 0.5    (+)
#             u     cprob      conditional probability ratio              (+)
#             j     import     importance (binary log. of prob. ratio)    (+)
#             z     cert       certainty factor (relative conf. change)   (+)
#             n     chi2       normalized chi^2 measure                   (+)
#             p     chi2pval   p-value f/ (unnormalized) chi^2 measure    (-)
#             y     yates      normalized chi^2 with Yates' correction    (+)
#             t     yatespval  p-value f/ Yates-corrected chi^2 measure   (-)
#             i     info       information difference to prior            (+)
#             g     infopval   p-value f/ G statistic/info. difference    (-)
#             f     fetprob    Fisher's exact test (table probability)    (-)
#             h     fetchi2    Fisher's exact test (chi^2 measure)        (-)
#             m     fetinfo    Fisher's exact test (mutual information)   (-)
#             s     fetsupp    Fisher's exact test (support)              (-)
#             Measures marked with (+) must meet or exceed the threshold,
#             measures marked with (-) must not exceed the threshold
#             in order for the item set to be reported.
#     agg     evaluation measure aggregation mode    (default: x)
#             x     none       no aggregation (use first value)
#             m     min        minimum of individual measure values
#             n     max        maximum of individual measure values
#             a     avg        average of individual measure values
#     thresh  threshold for evaluation measure       (default: 10%)
#     prune   min. size for evaluation filtering     (default: no pruning)
#             = 0   backward filtering       (no subset check)
#             < 0   weak   forward filtering (one subset  must qualify)
#             > 0   strong forward filtering (all subsets must qualify)
#     algo    algorithm variant to use               (default: a)
#             b     basic      standard algorithm (only choice)
#     mode    operation mode indicators/flags        (default: None)
#             x     do not use perfect extension pruning
#             t/T   do not organize transactions as a prefix tree
#             y     a-posteriori pruning of infrequent item sets
#             z     invalidate evaluation below expected support
#             o     use original rule support definition (body & head)
#     border  support border for filtering item sets (default: None)
#             Must be a list or tuple of (absolute) minimum support values
#             per item set size (by which the list/tuple is indexed).
#     appear  dictionary mapping items to item appearance indicators,
#             with the key None referring to the default item appearance.
#             (If None does not occur as a key or no dictionary is given,
#             the default item appearance indicator is 'both'.)
#             This parameter is only used if the target type is rules.
#             * item may not appear anywhere in a rule:
#               '-', 'n', 'none', 'neither', 'ignore'
#             * item may appear only in rule body/antecedent:
#               'i', 'in', 'inp', 'input', 'b', 'body',
#               'a', 'ante', 'antecedent'
#             * item may appear only in rule head/consequent:
#               'o', 'out',      'output', 'h', 'head',
#               'c', 'cons', 'consequent'
#             * item may appear anywhere in a rule:
#               'io', 'i&o', 'inout', 'in&out', 'bh', 'b&h', 'both'
#     returns if report is not in ['#','=','|']:
#               if the target is association rules:
#                 a list of rules (i.e. tuples with two or more elements),
#                 each consisting of a head/consequent item, a tuple with
#                 a body/antecedent item set, and the values selected by
#                 the parameter 'report', which may be combined into a
#                 tuple or a list if report[0] is '(' or '[', respectively.
#               if the target is a type of item sets:
#                 a list of patterns (i.e. tuples with one or more elements),
#                 each consisting of a tuple with a found frequent item set
#                 and the values selected by the parameter 'report', which
#                 may be combined into a tuple or list if report[0] is '('
#                 or '[', respectively
#             if report in ['#','=','|']:
#               a pattern spectrum as a dictionary mapping pattern sizes
#               to the corresponding occurrence support ranges, as a list
#               of triplets (size, min. support, max. support) or as three
#               columns for sizes and minimum and maximum support values

# %% [markdown]
# High support can mean that the consequence is simply very popular, and not because I am buying them together, so there is no real correlation.
# Confidence: how many time you find the consequence, given the premise

# %%
rules = apriori(baskets, supp=1, target='r', conf=3, eval='s')

# %%
print('Number of rule:', len(rules))
# Out:
# Number of rule: 20494

# %%
#visualization of one rule
# consequent, premise, confidence
rules[100]
# Out:
# (1188, (4271,), 1)

# %% [markdown]
# #### Given a rule, we can print the baksets that contain the premises of the rule

# %%
# premise
rules[9][1]
# Out:
# (3664,)

# %%
# consequent
rules[9][0]
# Out:
# 217

# %%
for b in baskets:
    if set(rules[9][1]) < set(b) and rules[9][0] in set(b):
            print(b)
# Out:
# [217, 3664, 4658, 5028]

# %% [markdown]
# # Pattern mining on tabular data

# %%
df = pd.read_csv("./datasets/titanic.csv", skipinitialspace=True, sep=',')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Some pre-processing steps

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

df['Age'] = df['Age'].groupby([df['Sex'], df['Pclass']], group_keys=False).apply(
    lambda x: x.fillna(x.median()))
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1 # size of the family= siblings + parch + and the person itself

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
column2drop = ['PassengerId', 'Name', 'Cabin', 'SibSp', 
               'Parch', 'Ticket']
df.drop(column2drop, axis=1, inplace=True)

df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  FamilySize
# 0         0       3    male  22.0   7.2500        S           2
# 1         1       1  female  38.0  71.2833        C           2
# 2         1       3  female  26.0   7.9250        S           1
# 3         1       1  female  35.0  53.1000        S           2
# 4         0       3    male  35.0   8.0500        S           1

# %% [markdown]
# Discretize into bins the continuous values as we need bins for apriori algorithm.

# %%
df['AgeBin'] = pd.cut(df['Age'].astype(int), 10, right=False)
df['FareBin'] = pd.cut(df['Fare'].astype(int), 10, right=False)

df.drop(['Age', 'Fare'], axis=1, inplace=True)

df.head()
# Out:
#    Survived  Pclass     Sex Embarked  FamilySize        AgeBin        FareBin
# 0         0       3    male        S           2  [16.0, 24.0)    [0.0, 51.2)
# 1         1       1  female        C           2  [32.0, 40.0)  [51.2, 102.4)
# 2         1       3  female        S           1  [24.0, 32.0)    [0.0, 51.2)
# 3         1       1  female        S           2  [32.0, 40.0)  [51.2, 102.4)
# 4         0       3    male        S           1  [32.0, 40.0)    [0.0, 51.2)

# %% [markdown]
# All vars are categorical at this point, but we need them in string format for the apriori algorithm. Add name of var to be understandable.

# %%
df['Survived'] = df['Survived'].map(
    {0: 'Not Survived', 1: 'Survived'}).astype(str)
df['Pclass'] = df['Pclass'].map(
    {1: '1st', 2: '2nd', 3: '3rd'}).astype(str)

df['FamilySize'] = df['FamilySize'].astype(str) + '_Family'
df['AgeBin'] = df['AgeBin'].astype(str) + '_Age'
df['FareBin'] = df['FareBin'].astype(str) + '_Fare'

df.head()
# Out:
#        Survived Pclass     Sex Embarked FamilySize            AgeBin  \
# 0  Not Survived    3rd    male        S   2_Family  [16.0, 24.0)_Age
# 1      Survived    1st  female        C   2_Family  [32.0, 40.0)_Age
# 2      Survived    3rd  female        S   1_Family  [24.0, 32.0)_Age
# 3      Survived    1st  female        S   2_Family  [32.0, 40.0)_Age
# 4  Not Survived    3rd    male        S   1_Family  [32.0, 40.0)_Age
#
#               FareBin
# 0    [0.0, 51.2)_Fare
# 1  [51.2, 102.4)_Fare
# 2    [0.0, 51.2)_Fare
# 3  [51.2, 102.4)_Fare
# 4    [0.0, 51.2)_Fare

# %%
baskets = df.values.tolist()

# %%
baskets
# Out:
# [['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '5_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '6_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[64.0, 72.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '8_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '8_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '6_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '4_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '6_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '5_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '11_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'Q',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[460.8, 512.512)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'female',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'Q',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[153.6, 204.8)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '6_Family',
#   '[24.0, 32.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '8_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'Q',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '4_Family',
#   '[8.0, 16.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '6_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '6_Family',
#   '[64.0, 72.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[64.0, 72.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
# ...
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '5_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[460.8, 512.512)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '5_Family',
#   '[16.0, 24.0)_Age',
#   '[256.0, 307.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '3_Family',
#   '[64.0, 72.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '2_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '4_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '4_Family',
#   '[32.0, 40.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '5_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[204.8, 256.0)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '4_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '6_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '4_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '11_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '4_Family',
#   '[8.0, 16.0)_Age',
#   '[102.4, 153.6)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'C',
#   '2_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'C',
#   '3_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[48.0, 56.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '6_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'C',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '2_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '3_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '11_Family',
#   '[24.0, 32.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[32.0, 40.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '7_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[72.0, 80.08)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'C',
#   '3_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[153.6, 204.8)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '4_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '2_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[48.0, 56.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '11_Family',
#   '[16.0, 24.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'male',
#   'S',
#   '3_Family',
#   '[0.0, 8.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '3_Family',
#   '[40.0, 48.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Not Survived',
#   '1st',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[40.0, 48.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'C',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '3rd',
#   'female',
#   'C',
#   '1_Family',
#   '[8.0, 16.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'C',
#   '2_Family',
#   '[56.0, 64.0)_Age',
#   '[51.2, 102.4)_Fare'],
#  ['Survived',
#   '2nd',
#   'female',
#   'S',
#   '2_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'Q',
#   '6_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '2nd',
#   'male',
#   'S',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'female',
#   'S',
#   '1_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'female',
#   'S',
#   '4_Family',
#   '[16.0, 24.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Survived',
#   '1st',
#   'male',
#   'C',
#   '1_Family',
#   '[24.0, 32.0)_Age',
#   '[0.0, 51.2)_Fare'],
#  ['Not Survived',
#   '3rd',
#   'male',
#   'Q',
#   '1_Family',
#   '[32.0, 40.0)_Age',
#   '[0.0, 51.2)_Fare']]

# %%
baskets[0]
# Out:
# ['Not Survived',
#  '3rd',
#  'male',
#  'S',
#  '2_Family',
#  '[16.0, 24.0)_Age',
#  '[0.0, 51.2)_Fare']

# %% [markdown]
# #### We apply apriori on the baskets

# %%
rules = apriori(baskets, supp=2, target='r', conf=2, eval='s')

# %%
rules
# Out:
# [('[72.0, 80.08)_Age',
#   ('1st', 'Survived', '1_Family', 'male', '[0.0, 51.2)_Fare'),
#   1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '1_Family', 'male'), 1),
#  ('[72.0, 80.08)_Age',
#   ('1st', 'Survived', '1_Family', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '1_Family', 'S'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '1_Family', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'male', 'S'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'male', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'male'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', 'S', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age', ('1st', 'Survived', '[0.0, 51.2)_Fare'), 1),
#  ('[72.0, 80.08)_Age',
#   ('Survived', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'),
#   1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', '1st', 'Survived'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', '1st', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'female', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'female'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'Survived', 'S'), 1),
#  ('[153.6, 204.8)_Fare', ('[40.0, 48.0)_Age', 'Survived'), 1),
#  ('[153.6, 204.8)_Fare', ('3_Family', '1st', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', '1st'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', '[24.0, 32.0)_Age'), 1),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'female'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('3_Family', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', '[24.0, 32.0)_Age', 'Survived'), 1),
#  ('[153.6, 204.8)_Fare', ('1st', '[24.0, 32.0)_Age'), 1),
#  ('[153.6, 204.8)_Fare', ('1st', 'female', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'female', 'Survived'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'female', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'female'), 2),
#  ('[153.6, 204.8)_Fare', ('1st', 'Survived', 'S'), 2),
#  ('[153.6, 204.8)_Fare', ('[24.0, 32.0)_Age', 'female', 'Survived', 'S'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '2_Family', '1st'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '2_Family', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'C', '1st'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'C'), 3),
#  ('[460.8, 512.512)_Fare',
#   ('[32.0, 40.0)_Age', '1st', 'female', 'Survived'),
#   1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', 'female'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1st'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'female', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'Survived', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('[32.0, 40.0)_Age',), 3),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'C', '1st', 'Survived'), 1),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'C', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('2_Family', 'Survived', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'female', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('C', '1st', '1_Family', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('C', '1st', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', '1st', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('C', '1st'), 3),
#  ('[460.8, 512.512)_Fare', ('C', 'female', 'Survived', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('C', 'female', '1_Family'), 1),
#  ('[460.8, 512.512)_Fare', ('C', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', 'Survived', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('C', 'Survived'), 3),
#  ('[460.8, 512.512)_Fare', ('C', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('C', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived', '1_Family', 'male'), 1),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived', '1_Family'), 2),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived', 'male'), 2),
#  ('[460.8, 512.512)_Fare', ('1st', 'Survived'), 3),
#  ('8_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   3),
#  ('8_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', '3rd'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', 'S'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 3),
#  ('8_Family', ('[8.0, 16.0)_Age',), 3),
#  ('8_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', '3rd', 'Not Survived', 'S'), 2),
#  ('8_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', '3rd', 'Not Survived'), 2),
#  ('8_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', 'Not Survived', 'S'), 2),
#  ('8_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('8_Family', ('female', 'Not Survived'), 2),
#  ('8_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('8_Family', ('3rd', 'Not Survived', 'S'), 6),
#  ('[256.0, 307.2)_Fare', ('6_Family', 'Not Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('6_Family',), 4),
#  ('[256.0, 307.2)_Fare', ('C', '[16.0, 24.0)_Age', 'female'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '[16.0, 24.0)_Age', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '[16.0, 24.0)_Age'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '1st', 'female', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '1st', 'female'), 2),
#  ('[256.0, 307.2)_Fare', ('C', '1st', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', 'female', 'Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('C', 'female'), 2),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st', 'female', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st', 'female'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', '1st'), 4),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'female', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'female'), 3),
#  ('[256.0, 307.2)_Fare', ('[16.0, 24.0)_Age', 'Survived'), 3),
#  ('[256.0, 307.2)_Fare', ('1st', 'female', 'Survived', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'female', 'Survived'), 4),
#  ('[256.0, 307.2)_Fare', ('1st', 'female', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'female'), 4),
#  ('[256.0, 307.2)_Fare', ('1st', 'Survived', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Survived'), 4),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived', 'male', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived', 'male'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'Not Survived'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'male', 'S'), 2),
#  ('[256.0, 307.2)_Fare', ('1st', 'S'), 4),
#  ('[256.0, 307.2)_Fare', ('1st',), 6),
#  ('11_Family', ('[51.2, 102.4)_Fare', '[24.0, 32.0)_Age', 'male'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', '[24.0, 32.0)_Age', 'S'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', '[24.0, 32.0)_Age'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'female', 'S'), 3),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'female'), 3),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived', 'male', 'S'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived', 'male'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived', 'S'), 7),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'Not Survived'), 7),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'male', 'S'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'male'), 4),
#  ('11_Family', ('[51.2, 102.4)_Fare', 'S'), 7),
#  ('11_Family', ('[51.2, 102.4)_Fare',), 7),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', '3rd'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'female'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', '3rd', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'Not Survived', 'S'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'Not Survived'), 3),
#  ('11_Family', ('[16.0, 24.0)_Age', 'S'), 3),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived', 'male', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived', 'male'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'Not Survived'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'male', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'male'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', '3rd'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'Not Survived', 'male', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'Not Survived', 'male'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'Not Survived', 'S'), 4),
#  ('11_Family', ('[24.0, 32.0)_Age', 'male', 'S'), 4),
#  ('11_Family', ('female', '3rd', 'Not Survived', 'S'), 3),
#  ('11_Family', ('female', '3rd', 'Not Survived'), 3),
#  ('11_Family', ('female', '3rd', 'S'), 3),
#  ('11_Family', ('female', '3rd'), 3),
#  ('11_Family', ('female', 'Not Survived', 'S'), 3),
#  ('11_Family', ('female', 'Not Survived'), 3),
#  ('11_Family', ('3rd', 'Not Survived', 'S'), 7),
#  ('[64.0, 72.0)_Age',
#   ('Q', '3rd', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '3rd', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '3rd', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('Q', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('Q', 'male'), 2),
#  ('[64.0, 72.0)_Age',
#   ('[51.2, 102.4)_Fare', '1st', 'Not Survived', 'male'),
#   2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'Not Survived', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('[51.2, 102.4)_Fare', 'Not Survived'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', '1_Family', 'male'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', '1_Family', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', '1_Family'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'Not Survived', 'male'), 3),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'Not Survived'), 3),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st', 'male'), 3),
#  ('[64.0, 72.0)_Age', ('C', '1st', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('C', '1st'), 3),
#  ('[64.0, 72.0)_Age',
#   ('C', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age',
#   ('C', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('C', 'Not Survived', 'male'), 3),
#  ('[64.0, 72.0)_Age', ('C', 'Not Survived'), 3),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived', 'male', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived', 'male'), 4),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived', 'S'), 2),
#  ('[64.0, 72.0)_Age',
#   ('1st', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'Not Survived'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', 'male'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '1_Family'), 4),
#  ('[64.0, 72.0)_Age',
#   ('1st', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'male', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'male'), 7),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'Not Survived'), 7),
#  ('[64.0, 72.0)_Age', ('1st', 'male', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st', 'male'), 7),
#  ('[64.0, 72.0)_Age', ('1st', 'S'), 4),
#  ('[64.0, 72.0)_Age', ('1st', '[0.0, 51.2)_Fare'), 4),
#  ('[64.0, 72.0)_Age', ('1st',), 7),
#  ('[64.0, 72.0)_Age',
#   ('1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'Not Survived', 'male'), 8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'Not Survived', '[0.0, 51.2)_Fare'), 8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'Not Survived'), 8),
#  ('[64.0, 72.0)_Age', ('1_Family', 'male', '[0.0, 51.2)_Fare'), 8),
#  ('[64.0, 72.0)_Age', ('Not Survived', 'male'), 11),
#  ('[64.0, 72.0)_Age', ('Not Survived',), 11),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', '1_Family', 'Not Survived', 'male'),
#   2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', '1_Family', 'Not Survived'),
#   2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', '1_Family', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1st', 'Not Survived', 'male'),
#   2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'Not Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1st'), 4),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'female'), 2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare',
#   ('[40.0, 48.0)_Age', '1_Family', 'Not Survived', 'male'),
#   2),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('[40.0, 48.0)_Age',), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st', 'female', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st', 'female'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', '1st'), 3),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', 'female', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', 'female'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C', 'Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'C'), 3),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female', 'Survived', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'Survived', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', '1st'), 5),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'female', 'Survived', 'S'), 2),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('2_Family',), 5),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'female', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Survived', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1st', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Not Survived', 'male'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'Not Survived'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st', 'male'), 3),
#  ('[204.8, 256.0)_Fare', ('C', '1st'), 7),
#  ('[204.8, 256.0)_Fare', ('C', '[24.0, 32.0)_Age', 'Not Survived', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '[24.0, 32.0)_Age', 'Not Survived'), 2),
#  ('[204.8, 256.0)_Fare', ('C', '[24.0, 32.0)_Age', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'female', 'Survived', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'female', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', 'female', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'female'), 4),
#  ('[204.8, 256.0)_Fare', ('C', 'Survived', '1_Family'), 2),
#  ('[204.8, 256.0)_Fare', ('C', 'Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('C', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('C', 'Not Survived', 'male'), 3),
#  ('[204.8, 256.0)_Fare', ('C', 'Not Survived'), 3),
#  ('[204.8, 256.0)_Fare', ('C',), 7),
#  ('[204.8, 256.0)_Fare', ('1st', '[24.0, 32.0)_Age', 'male'), 2),
#  ('[204.8, 256.0)_Fare', ('1st', '[24.0, 32.0)_Age'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'Survived', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'Survived', 'S'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'Survived'), 7),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female', 'S'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'female'), 7),
#  ('[204.8, 256.0)_Fare', ('1st', 'Survived', '1_Family'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'Survived', 'S'), 3),
#  ('[204.8, 256.0)_Fare', ('1st', 'Survived'), 7),
#  ('[204.8, 256.0)_Fare', ('1st', '1_Family'), 5),
#  ('[204.8, 256.0)_Fare', ('1st', 'Not Survived', 'male'), 4),
#  ('[204.8, 256.0)_Fare', ('1st', 'Not Survived'), 4),
#  ('[204.8, 256.0)_Fare', ('1st', 'male'), 4),
#  ('[204.8, 256.0)_Fare', ('1st', 'S'), 4),
#  ('[204.8, 256.0)_Fare', ('1st',), 11),
#  ('[204.8, 256.0)_Fare', ('female', 'Survived'), 7),
#  ('[204.8, 256.0)_Fare', ('female',), 7),
#  ('[204.8, 256.0)_Fare', ('Survived',), 7),
#  ('7_Family', ('[8.0, 16.0)_Age', 'female'), 2),
#  ('7_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   3),
#  ('7_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', '3rd'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', 'S'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[8.0, 16.0)_Age',), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female', 'S'), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'female'), 3),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived', 'S'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'Survived'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd', 'S'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '3rd'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male', 'S'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'male'), 2),
#  ('7_Family', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', 'S'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('[0.0, 8.0)_Age',), 5),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', 'S'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', 'female', '[0.0, 51.2)_Fare'), 2),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   2),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'Not Survived', 'S'), 2),
#  ('7_Family',
#   ('[32.0, 40.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'Not Survived'), 2),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', 'S'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', '3rd'), 3),
#  ('7_Family', ('[32.0, 40.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('female', 'Survived', '3rd', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('female', 'Survived', '3rd', 'S'), 3),
#  ('7_Family', ('female', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('7_Family', ('female', 'Survived', '3rd'), 3),
#  ('7_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', '3rd', 'Not Survived', 'S'), 5),
#  ('7_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', '3rd', 'Not Survived'), 5),
#  ('7_Family', ('female', '3rd', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female', '3rd', 'S'), 8),
#  ('7_Family', ('female', '3rd', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female', '3rd'), 8),
#  ('7_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', 'Not Survived', 'S'), 5),
#  ('7_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('7_Family', ('female', 'Not Survived'), 5),
#  ('7_Family', ('female', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female', 'S'), 8),
#  ('7_Family', ('female', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('female',), 8),
#  ('7_Family', ('Survived', '3rd', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('7_Family', ('Survived', '3rd', 'S'), 4),
#  ('7_Family', ('Survived', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('7_Family', ('Survived', '3rd'), 4),
#  ('7_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('3rd', 'Not Survived', 'S'), 8),
#  ('7_Family', ('3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('3rd', 'Not Survived'), 8),
#  ('7_Family', ('3rd', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('7_Family', ('3rd', 'S'), 12),
#  ('7_Family', ('3rd', '[0.0, 51.2)_Fare'), 12),
#  ('7_Family', ('3rd',), 12),
#  ('7_Family', ('Not Survived', 'S', '[0.0, 51.2)_Fare'), 8),
#  ('7_Family', ('S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('[8.0, 16.0)_Age', 'female'), 2),
#  ('5_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   2),
#  ('5_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', '3rd'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', 'S'), 2),
#  ('5_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd', 'S'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[0.0, 8.0)_Age', '3rd'), 2),
#  ('5_Family', ('[48.0, 56.0)_Age', 'female'), 2),
#  ('5_Family', ('[48.0, 56.0)_Age', 'S', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('[48.0, 56.0)_Age', '[0.0, 51.2)_Fare'), 2),
#  ('5_Family', ('C', '[16.0, 24.0)_Age', 'female'), 2),
#  ('5_Family', ('C', '[16.0, 24.0)_Age', 'Survived'), 2),
#  ('5_Family', ('C', '[16.0, 24.0)_Age'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st', 'female', 'Survived'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st', 'female'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st', 'Survived'), 2),
#  ('5_Family', ('[16.0, 24.0)_Age', '1st'), 2),
#  ('5_Family',
#   ('[16.0, 24.0)_Age',
#    'female',
#    '3rd',
#    'Not Survived',
#    'S',
#    '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', 'S'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'Not Survived'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', '3rd', 'S', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', 'S'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '3rd'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived', 'S'), 4),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'female', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'Not Survived'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', 'S'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female', '[0.0, 51.2)_Fare'), 4),
#  ('5_Family', ('[16.0, 24.0)_Age', 'female'), 6),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived', 'S'), 5),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'Not Survived'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', 'S'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', '3rd'), 5),
#  ('5_Family',
#   ('[16.0, 24.0)_Age', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'Not Survived', 'S'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'Not Survived'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age', 'S'), 5),
#  ('5_Family', ('[16.0, 24.0)_Age',), 7),
#  ('5_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd', 'Not Survived', 'S'), 9),
#  ('5_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd', 'Not Survived'), 9),
#  ('5_Family', ('female', '3rd', 'S', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd', 'S'), 9),
#  ('5_Family', ('female', '3rd', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', '3rd'), 9),
#  ('5_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', 'Not Survived', 'S'), 9),
#  ('5_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 9),
#  ('5_Family', ('female', 'Not Survived'), 9),
#  ('5_Family', ('female', 'S', '[0.0, 51.2)_Fare'), 10),
#  ('5_Family', ('female', 'S'), 10),
#  ('5_Family', ('female', '[0.0, 51.2)_Fare'), 10),
#  ('5_Family', ('female',), 12),
#  ('5_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd', 'Not Survived', 'S'), 12),
#  ('5_Family', ('3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd', 'Not Survived'), 12),
#  ('5_Family', ('3rd', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd', 'S'), 12),
#  ('5_Family', ('3rd', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('3rd',), 12),
#  ('5_Family', ('Not Survived', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('Not Survived', 'S'), 12),
#  ('5_Family', ('Not Survived', '[0.0, 51.2)_Fare'), 12),
#  ('5_Family', ('S', '[0.0, 51.2)_Fare'), 13),
#  ('6_Family',
#   ('[8.0, 16.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('6_Family', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', '3rd'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 4),
#  ('[8.0, 16.0)_Age', ('6_Family', 'Not Survived'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', 'Not Survived'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[8.0, 16.0)_Age', 'S'), 3),
#  ('[8.0, 16.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 4),
#  ('[8.0, 16.0)_Age', ('6_Family',), 4),
#  ('6_Family', ('[8.0, 16.0)_Age',), 4),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd', 'S'), 5),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('[0.0, 8.0)_Age', '3rd'), 8),
#  ('[0.0, 8.0)_Age', ('6_Family', 'Not Survived'), 8),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male', 'S'), 4),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male', '[0.0, 51.2)_Fare'), 7),
#  ('6_Family', ('[0.0, 8.0)_Age', 'male'), 7),
#  ('6_Family', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('[0.0, 8.0)_Age', 'S'), 5),
#  ('[0.0, 8.0)_Age', ('6_Family', '[0.0, 51.2)_Fare'), 8),
#  ('6_Family', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 8),
#  ('[0.0, 8.0)_Age', ('6_Family',), 8),
#  ('6_Family', ('[0.0, 8.0)_Age',), 8),
#  ('6_Family', ('Q', '3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', '3rd', 'Not Survived', 'male'), 4),
#  ('6_Family', ('Q', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('Q', '3rd', 'Not Survived'), 5),
#  ('6_Family', ('Q', '3rd', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', '3rd', 'male'), 4),
#  ('6_Family', ('Q', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('Q', '3rd'), 5),
#  ('6_Family', ('Q', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', 'Not Survived', 'male'), 4),
#  ('6_Family', ('Q', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('Q', ('6_Family', 'Not Survived'), 5),
#  ('6_Family', ('Q', 'Not Survived'), 5),
#  ('6_Family', ('Q', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('Q', 'male'), 4),
#  ('Q', ('6_Family', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('Q', '[0.0, 51.2)_Fare'), 5),
#  ('Q', ('6_Family',), 5),
#  ('6_Family', ('Q',), 5),
#  ('6_Family', ('[40.0, 48.0)_Age', 'female', 'S'), 2),
#  ('6_Family', ('[40.0, 48.0)_Age', 'female', '[0.0, 51.2)_Fare'), 2),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'Not Survived', 'S'), 3),
#  ('6_Family',
#   ('[40.0, 48.0)_Age', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'Not Survived'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', 'S'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('6_Family', ('[40.0, 48.0)_Age', '3rd'), 3),
#  ('6_Family', ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('female', '3rd', 'Not Survived', 'S'), 4),
#  ('6_Family', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('female', '3rd', 'Not Survived'), 5),
#  ('6_Family', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('6_Family', ('female', 'Not Survived', 'S'), 4),
#  ('6_Family', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 5),
#  ('6_Family', ('female', 'Not Survived'), 5),
#  ('6_Family', ('3rd', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('3rd', 'Not Survived', 'male'), 12),
#  ('6_Family', ('3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('3rd', 'Not Survived', 'S'), 12),
#  ('6_Family', ('3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 17),
#  ('3rd', ('6_Family', 'Not Survived'), 17),
#  ('6_Family', ('3rd', 'Not Survived'), 17),
#  ('6_Family', ('3rd', 'male', '[0.0, 51.2)_Fare'), 12),
#  ('6_Family', ('3rd', 'male'), 12),
#  ('6_Family', ('3rd', 'S', '[0.0, 51.2)_Fare'), 12),
#  ('3rd', ('6_Family', '[0.0, 51.2)_Fare'), 17),
#  ('6_Family', ('3rd', '[0.0, 51.2)_Fare'), 17),
#  ('3rd', ('6_Family',), 17),
#  ('6_Family', ('3rd',), 17),
#  ('Not Survived', ('6_Family', '[0.0, 51.2)_Fare'), 17),
#  ('6_Family', ('Not Survived', '[0.0, 51.2)_Fare'), 17),
#  ('Not Survived', ('6_Family',), 19),
#  ('6_Family', ('Not Survived',), 19),
#  ('[56.0, 64.0)_Age', ('[102.4, 153.6)_Fare', '1st', 'female', 'Survived'), 2),
#  ('[102.4, 153.6)_Fare', ('[56.0, 64.0)_Age', '1st'), 3),
#  ('[56.0, 64.0)_Age', ('[102.4, 153.6)_Fare', '1st'), 3),
#  ('[56.0, 64.0)_Age', ('[102.4, 153.6)_Fare', 'female', 'Survived'), 2),
#  ('[102.4, 153.6)_Fare', ('[56.0, 64.0)_Age',), 3),
#  ('[56.0, 64.0)_Age', ('[102.4, 153.6)_Fare',), 3),
#  ('[56.0, 64.0)_Age',
#   ('[51.2, 102.4)_Fare', '2_Family', 'C', '1st', 'Survived'),
#   2),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', 'C', 'Survived'), 2),
#  ('[56.0, 64.0)_Age',
#   ('[51.2, 102.4)_Fare', '2_Family', '1st', 'female', 'Survived'),
#   3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', '1st', 'female'), 3),
#  ('[56.0, 64.0)_Age',
#   ('[51.2, 102.4)_Fare', '2_Family', '1st', 'Survived'),
#   3),
#  ('[56.0, 64.0)_Age',
#   ('[51.2, 102.4)_Fare', '2_Family', 'female', 'Survived'),
#   3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', 'female'), 3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '2_Family', 'Survived'), 3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', 'C', '1st', 'Survived'), 3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', 'C', '1st'), 3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', 'C', 'Survived'), 3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', 'C'), 3),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'female', 'Survived'), 4),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'female'), 4),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '1st', 'Survived'), 5),
#  ('[51.2, 102.4)_Fare', ('[56.0, 64.0)_Age', '1st'), 5),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', '1st'), 5),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', 'female', 'Survived'), 4),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', 'female'), 4),
#  ('[56.0, 64.0)_Age', ('[51.2, 102.4)_Fare', 'Survived'), 5),
#  ('[56.0, 64.0)_Age', ('2_Family', '1st', 'female', 'Survived'), 4),
#  ('[56.0, 64.0)_Age', ('2_Family', '1st', 'female'), 4),
#  ('[56.0, 64.0)_Age', ('2_Family', '1st', 'Survived'), 4),
#  ('[56.0, 64.0)_Age', ('C', '1st', 'Survived'), 5),
#  ('[56.0, 64.0)_Age', ('C', '1st', '1_Family', 'male'), 3),
#  ('[56.0, 64.0)_Age', ('C', '1st', '1_Family', '[0.0, 51.2)_Fare'), 3),
#  ('[56.0, 64.0)_Age', ('C', '1st', '1_Family'), 4),
#  ('[56.0, 64.0)_Age', ('C', '1st', 'Not Survived', 'male'), 3),
#  ('[56.0, 64.0)_Age', ('C', '1st', 'Not Survived'), 3),
#  ('[56.0, 64.0)_Age', ('C', '1st', 'male', '[0.0, 51.2)_Fare'), 3),
#  ('[56.0, 64.0)_Age', ('C', '1st', 'male'), 5),
#  ('[56.0, 64.0)_Age', ('C', '1st', '[0.0, 51.2)_Fare'), 3),
#  ('C', ('[56.0, 64.0)_Age', '1st'), 8),
#  ('[56.0, 64.0)_Age', ('C', '1st'), 8),
#  ('C', ('[56.0, 64.0)_Age',), 8),
#  ('[56.0, 64.0)_Age', ('C',), 8),
#  ('[56.0, 64.0)_Age', ('1st', 'female', 'Survived', '1_Family'), 3),
#  ('[56.0, 64.0)_Age', ('1st', 'female', 'Survived', 'S'), 4),
#  ('[56.0, 64.0)_Age', ('1st', 'female', 'Survived'), 7),
#  ('[56.0, 64.0)_Age', ('1st', 'female', '1_Family'), 3),
#  ('[56.0, 64.0)_Age', ('1st', 'female', 'S'), 4),
#  ('[56.0, 64.0)_Age', ('1st', 'female'), 7),
#  ('[56.0, 64.0)_Age', ('1st', 'Survived', '1_Family'), 4),
#  ('[56.0, 64.0)_Age', ('1st', 'Survived'), 9),
#  ('[56.0, 64.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   6),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'Not Survived', 'male', 'S'), 6),
#  ('[56.0, 64.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'male', '[0.0, 51.2)_Fare'),
#   8),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'Not Survived', 'male'), 8),
#  ('[56.0, 64.0)_Age',
#   ('1st', '1_Family', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   6),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'Not Survived', 'S'), 6),
#  ('[56.0, 64.0)_Age',
#   ('1st', '1_Family', 'Not Survived', '[0.0, 51.2)_Fare'),
#   8),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'Not Survived'), 8),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'male', 'S'), 6),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'male', '[0.0, 51.2)_Fare'), 9),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'male'), 9),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'S', '[0.0, 51.2)_Fare'), 7),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', 'S'), 8),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family', '[0.0, 51.2)_Fare'), 10),
#  ('1st', ('[56.0, 64.0)_Age', '1_Family'), 12),
#  ('[56.0, 64.0)_Age', ('1st', '1_Family'), 12),
#  ('[56.0, 64.0)_Age',
#   ('1st', 'Not Survived', 'male', 'S', '[0.0, 51.2)_Fare'),
#   6),
#  ('[56.0, 64.0)_Age', ('1st', 'Not Survived', 'male', 'S'), 6),
#  ('[56.0, 64.0)_Age', ('1st', 'Not Survived', 'male', '[0.0, 51.2)_Fare'), 8),
#  ('[56.0, 64.0)_Age', ('1st', 'Not Survived', 'male'), 9),
#  ('[56.0, 64.0)_Age', ('1st', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('[56.0, 64.0)_Age', ('1st', 'Not Survived', 'S'), 6),
#  ('[56.0, 64.0)_Age', ('1st', 'Not Survived', '[0.0, 51.2)_Fare'), 8),
#  ('[56.0, 64.0)_Age', ('1st', 'Not Survived'), 9),
#  ('[56.0, 64.0)_Age', ('1st', 'male', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('[56.0, 64.0)_Age', ('1st', 'male', 'S'), 6),
#  ('[56.0, 64.0)_Age', ('1st', 'male', '[0.0, 51.2)_Fare'), 9),
#  ('[56.0, 64.0)_Age', ('1st', 'male'), 11),
#  ('[56.0, 64.0)_Age', ('1st', 'S', '[0.0, 51.2)_Fare'), 7),
#  ('[56.0, 64.0)_Age', ('1st', 'S'), 10),
#  ('1st', ('[56.0, 64.0)_Age', '[0.0, 51.2)_Fare'), 10),
#  ('[56.0, 64.0)_Age', ('1st', '[0.0, 51.2)_Fare'), 10),
#  ('1st', ('[56.0, 64.0)_Age',), 18),
#  ('[56.0, 64.0)_Age', ('1st',), 18),
#  ('1_Family', ('[56.0, 64.0)_Age', '[0.0, 51.2)_Fare'), 17),
#  ('male', ('[56.0, 64.0)_Age', '[0.0, 51.2)_Fare'), 15),
#  ('4_Family', ('[102.4, 153.6)_Fare', '1st', 'female'), 4),
#  ('4_Family', ('[102.4, 153.6)_Fare', '1st', 'Survived'), 5),
#  ('4_Family', ('[102.4, 153.6)_Fare', '1st'), 7),
#  ('[102.4, 153.6)_Fare', ('4_Family', 'female'), 4),
#  ('4_Family', ('[102.4, 153.6)_Fare', 'female'), 4),
#  ('[102.4, 153.6)_Fare', ('4_Family', 'Survived'), 5),
#  ('4_Family', ('[102.4, 153.6)_Fare', 'Survived'), 5),
#  ('[102.4, 153.6)_Fare', ('4_Family', 'S'), 7),
#  ('[102.4, 153.6)_Fare', ('4_Family',), 7),
#  ('4_Family', ('[102.4, 153.6)_Fare',), 7),
#  ('4_Family', ('[0.0, 8.0)_Age', 'female', 'Survived', '[0.0, 51.2)_Fare'), 6),
#  ('4_Family', ('[0.0, 8.0)_Age', 'female', 'Survived'), 6),
#  ('4_Family', ('[0.0, 8.0)_Age', 'female', 'S'), 3),
#  ('4_Family', ('[0.0, 8.0)_Age', 'female', '[0.0, 51.2)_Fare'), 6),
#  ('[0.0, 8.0)_Age', ('4_Family', 'female'), 7),
#  ('4_Family', ('[0.0, 8.0)_Age', 'female'), 7),
#  ('4_Family', ('[0.0, 8.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('4_Family', ('[0.0, 8.0)_Age', 'Survived', 'S'), 5),
#  ('4_Family', ('[0.0, 8.0)_Age', 'Survived', '[0.0, 51.2)_Fare'), 8),
#  ('[0.0, 8.0)_Age', ('4_Family', 'Survived'), 9),
#  ('4_Family', ('[0.0, 8.0)_Age', 'Survived'), 9),
#  ('4_Family', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('4_Family', ('[0.0, 8.0)_Age', '3rd'), 4),
#  ('4_Family', ('[0.0, 8.0)_Age', 'male', 'S'), 3),
#  ('4_Family', ('[0.0, 8.0)_Age', 'male'), 3),
#  ('4_Family', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('[0.0, 8.0)_Age', ('4_Family', 'S'), 6),
#  ('4_Family', ('[0.0, 8.0)_Age', 'S'), 6),
#  ('[0.0, 8.0)_Age', ('4_Family', '[0.0, 51.2)_Fare'), 8),
#  ('4_Family', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 8),
#  ('[0.0, 8.0)_Age', ('4_Family',), 10),
#  ('4_Family', ('[0.0, 8.0)_Age',), 10),
#  ('4_Family', ('[32.0, 40.0)_Age', 'female', 'Survived', 'S'), 3),
#  ('4_Family', ('[32.0, 40.0)_Age', 'Survived', 'S'), 4),
#  ('4_Family', ('C', 'female', 'Survived', '[0.0, 51.2)_Fare'), 6),
#  ('4_Family', ('C', 'female', 'Survived'), 6),
#  ('4_Family', ('C', 'female', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('4_Family', ('C', 'female', '3rd'), 4),
#  ('4_Family', ('C', 'female', '[0.0, 51.2)_Fare'), 6),
#  ('4_Family', ('C', 'female'), 6),
#  ('4_Family', ('C', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('4_Family', ('C', 'Survived', '3rd'), 4),
#  ('4_Family', ('C', 'Survived', '[0.0, 51.2)_Fare'), 6),
#  ('4_Family', ('C', 'Survived'), 6),
#  ('C', ('4_Family', '[0.0, 51.2)_Fare'), 7),
#  ('4_Family', ('C', '[0.0, 51.2)_Fare'), 7),
#  ('4_Family', ('2nd', '[24.0, 32.0)_Age', 'female', 'Survived', 'S'), 3),
#  ('4_Family', ('2nd', '[24.0, 32.0)_Age', 'female', 'Survived'), 3),
#  ('4_Family', ('2nd', '[24.0, 32.0)_Age', 'female', 'S'), 3),
#  ('4_Family', ('2nd', '[24.0, 32.0)_Age', 'female'), 3),
#  ('4_Family', ('2nd', '[24.0, 32.0)_Age', 'Survived', 'S'), 3),
#  ('4_Family', ('2nd', '[24.0, 32.0)_Age', 'Survived'), 3),
#  ('4_Family', ('2nd', 'female', 'Survived', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('4_Family', ('2nd', 'female', 'Survived', 'S'), 7),
#  ('4_Family', ('2nd', 'female', 'Survived', '[0.0, 51.2)_Fare'), 7),
#  ('4_Family', ('2nd', 'female', 'Survived'), 9),
#  ('4_Family', ('2nd', 'female', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('4_Family', ('2nd', 'female', 'S'), 7),
#  ('4_Family', ('2nd', 'female', '[0.0, 51.2)_Fare'), 7),
#  ('2nd', ('4_Family', 'female'), 9),
#  ('4_Family', ('2nd', 'female'), 9),
#  ('4_Family', ('2nd', 'Survived', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('4_Family', ('2nd', 'Survived', 'S'), 8),
#  ('4_Family', ('2nd', 'Survived', '[0.0, 51.2)_Fare'), 8),
#  ('2nd', ('4_Family', 'Survived'), 10),
#  ('4_Family', ('2nd', 'Survived'), 10),
#  ('2nd', ('4_Family', 'S'), 10),
#  ('4_Family', ('2nd', 'S'), 10),
#  ('2nd', ('4_Family', '[0.0, 51.2)_Fare'), 11),
#  ('4_Family', ('2nd', '[0.0, 51.2)_Fare'), 11),
#  ('2nd', ('4_Family',), 13),
#  ('4_Family', ('2nd',), 13),
#  ('4_Family', ('1st', 'female', 'S'), 4),
#  ('4_Family', ('1st', 'Survived', 'male', 'S'), 3),
#  ('4_Family', ('1st', 'Survived', 'S'), 5),
#  ('4_Family', ('[24.0, 32.0)_Age', 'female', 'Survived'), 4),
#  ('4_Family', ('[24.0, 32.0)_Age', 'female', 'S'), 4),
#  ('4_Family', ('[24.0, 32.0)_Age', 'female'), 5),
#  ('4_Family', ('female', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('4_Family', ('female', 'Survived', '3rd'), 5),
#  ('4_Family', ('female', 'Survived', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('4_Family', ('female', 'Survived', 'S'), 10),
#  ('4_Family', ('female', 'Survived', '[0.0, 51.2)_Fare'), 12),
#  ('Survived', ('4_Family', 'female'), 16),
#  ('female', ('4_Family', 'Survived'), 16),
#  ('4_Family', ('female', 'Survived'), 16),
#  ('female', ('4_Family', 'S'), 13),
#  ('4_Family', ('female', 'S'), 13),
#  ('female', ('4_Family', '[0.0, 51.2)_Fare'), 13),
#  ('4_Family', ('female', '[0.0, 51.2)_Fare'), 13),
#  ('female', ('4_Family',), 19),
#  ('4_Family', ('female',), 19),
#  ('4_Family', ('Survived', 'male', 'S'), 5),
#  ('Survived', ('4_Family', 'S'), 15),
#  ('4_Family', ('Survived', 'S'), 15),
#  ('Survived', ('4_Family', '[0.0, 51.2)_Fare'), 14),
#  ('4_Family', ('Survived', '[0.0, 51.2)_Fare'), 14),
#  ('Survived', ('4_Family',), 21),
#  ('4_Family', ('Survived',), 21),
#  ('[102.4, 153.6)_Fare', ('[48.0, 56.0)_Age', '1st'), 3),
#  ('[102.4, 153.6)_Fare', ('[48.0, 56.0)_Age', 'male'), 3),
#  ('[102.4, 153.6)_Fare', ('[40.0, 48.0)_Age', '1st', 'Survived'), 3),
#  ('[102.4, 153.6)_Fare', ('[40.0, 48.0)_Age', 'female'), 3),
#  ('[102.4, 153.6)_Fare', ('[40.0, 48.0)_Age', 'Survived'), 3),
#  ('[102.4, 153.6)_Fare', ('3_Family', 'C'), 5),
#  ('[102.4, 153.6)_Fare', ('3_Family', '1st', 'Survived'), 4),
#  ('[102.4, 153.6)_Fare', ('3_Family', '1st'), 6),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '2_Family', '1st'), 3),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '2_Family'), 3),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'C', '1st'), 4),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'C'), 4),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare', '1st', 'female', 'Survived'), 7),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '1st', 'female', 'Survived'), 7),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare', '1st', 'female'), 7),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '1st', 'female'), 7),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '1st', 'Survived', 'S'), 4),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare', '1st', 'Survived'), 8),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '1st', 'Survived'), 8),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '1st', '1_Family'), 3),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '1st', 'S'), 5),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare', '1st'), 9),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', '1st'), 9),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'female', 'Survived', 'S'), 3),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare', 'female', 'Survived'), 7),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'female', 'Survived'), 7),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'female', '1_Family'), 3),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare', 'female'), 7),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'female'), 7),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'Survived', '1_Family'), 3),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'Survived', 'S'), 4),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare', 'Survived'), 8),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age', 'Survived'), 8),
#  ('[32.0, 40.0)_Age', ('[102.4, 153.6)_Fare',), 9),
#  ('[102.4, 153.6)_Fare', ('[32.0, 40.0)_Age',), 9),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C', '1st', 'female', 'Survived'), 4),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C', '1st', 'female'), 4),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C', '1st', 'Survived'), 4),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C', '1st'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C', 'female', 'Survived'), 4),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C', 'female'), 4),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C', 'Survived'), 4),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'C'), 6),
#  ('2_Family', ('[102.4, 153.6)_Fare', '1st', 'female', 'Survived'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', '1st', 'female', 'Survived'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', '1st', 'female'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', '1st', 'Survived'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', '1st', 'Not Survived', 'male'), 3),
#  ('[102.4, 153.6)_Fare', ('2_Family', '1st', 'Not Survived'), 3),
#  ('[102.4, 153.6)_Fare', ('2_Family', '1st', 'male'), 3),
#  ('2_Family', ('[102.4, 153.6)_Fare', '1st'), 9),
#  ('[102.4, 153.6)_Fare', ('2_Family', '1st'), 9),
#  ('2_Family', ('[102.4, 153.6)_Fare', 'female', 'Survived'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'female', 'Survived'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'female'), 6),
#  ('[102.4, 153.6)_Fare', ('2_Family', 'Survived'), 6),
#  ('2_Family', ('[102.4, 153.6)_Fare',), 9),
#  ('[102.4, 153.6)_Fare', ('2_Family',), 9),
#  ('[102.4, 153.6)_Fare', ('C', '[16.0, 24.0)_Age', 'Survived'), 3),
#  ('[102.4, 153.6)_Fare', ('C', '[16.0, 24.0)_Age'), 5),
#  ('C', ('[102.4, 153.6)_Fare', '1st', 'female', 'Survived'), 11),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'female', 'Survived'), 11),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'female', '1_Family'), 5),
#  ('C', ('[102.4, 153.6)_Fare', '1st', 'female'), 11),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'female'), 11),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'Survived', '1_Family'), 5),
#  ('C', ('[102.4, 153.6)_Fare', '1st', 'Survived'), 12),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'Survived'), 12),
#  ('[102.4, 153.6)_Fare', ('C', '1st', '1_Family'), 6),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'Not Survived', 'male'), 5),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'Not Survived'), 5),
#  ('[102.4, 153.6)_Fare', ('C', '1st', 'male'), 6),
#  ('C', ('[102.4, 153.6)_Fare', '1st'), 17),
#  ('[102.4, 153.6)_Fare', ('C', '1st'), 17),
#  ('[102.4, 153.6)_Fare', ('C', 'female', 'Survived', '1_Family'), 5),
#  ('C', ('[102.4, 153.6)_Fare', 'female', 'Survived'), 11),
#  ('[102.4, 153.6)_Fare', ('C', 'female', 'Survived'), 11),
#  ('[102.4, 153.6)_Fare', ('C', 'female', '1_Family'), 5),
#  ('C', ('[102.4, 153.6)_Fare', 'female'), 11),
#  ('[102.4, 153.6)_Fare', ('C', 'female'), 11),
#  ('[102.4, 153.6)_Fare', ('C', 'Survived', '1_Family'), 5),
#  ('C', ('[102.4, 153.6)_Fare', 'Survived'), 12),
#  ('[102.4, 153.6)_Fare', ('C', 'Survived'), 12),
#  ('[102.4, 153.6)_Fare', ('C', '1_Family'), 6),
#  ('[102.4, 153.6)_Fare', ('C', 'Not Survived', 'male'), 5),
#  ('C', ('[102.4, 153.6)_Fare',), 17),
#  ('[102.4, 153.6)_Fare', ('C',), 17),
#  ('[102.4, 153.6)_Fare', ('[16.0, 24.0)_Age', '1st', 'female', 'Survived'), 3),
#  ('[102.4, 153.6)_Fare', ('[16.0, 24.0)_Age', '1st', 'female'), 3),
#  ('[102.4, 153.6)_Fare', ('[16.0, 24.0)_Age', '1st', 'Survived'), 4),
#  ('[102.4, 153.6)_Fare', ('[16.0, 24.0)_Age', '1st'), 6),
#  ('[102.4, 153.6)_Fare', ('1st', 'female', 'Survived', '1_Family'), 8),
#  ('[102.4, 153.6)_Fare', ('1st', 'female', 'Survived', 'S'), 7),
#  ('Survived', ('[102.4, 153.6)_Fare', '1st', 'female'), 18),
#  ('female', ('[102.4, 153.6)_Fare', '1st', 'Survived'), 18),
#  ('1st', ('[102.4, 153.6)_Fare', 'female', 'Survived'), 18),
#  ('[102.4, 153.6)_Fare', ('1st', 'female', 'Survived'), 18),
#  ('[102.4, 153.6)_Fare', ('1st', 'female', '1_Family'), 8),
#  ('[102.4, 153.6)_Fare', ('1st', 'female', 'S'), 9),
#  ('female', ('[102.4, 153.6)_Fare', '1st'), 20),
#  ('1st', ('[102.4, 153.6)_Fare', 'female'), 20),
#  ('[102.4, 153.6)_Fare', ('1st', 'female'), 20),
#  ('[102.4, 153.6)_Fare', ('1st', 'Survived', '1_Family'), 8),
#  ('[102.4, 153.6)_Fare', ('1st', 'Survived', 'male', 'S'), 4),
#  ('[102.4, 153.6)_Fare', ('1st', 'Survived', 'male'), 5),
#  ('[102.4, 153.6)_Fare', ('1st', 'Survived', 'S'), 11),
#  ('Survived', ('[102.4, 153.6)_Fare', '1st'), 23),
#  ('1st', ('[102.4, 153.6)_Fare', 'Survived'), 23),
#  ('[102.4, 153.6)_Fare', ('1st', 'Survived'), 23),
#  ('[102.4, 153.6)_Fare', ('1st', '1_Family'), 9),
#  ('[102.4, 153.6)_Fare', ('1st', 'Not Survived', 'male'), 6),
#  ('[102.4, 153.6)_Fare', ('1st', 'Not Survived'), 8),
#  ('[102.4, 153.6)_Fare', ('1st', 'male'), 11),
#  ('[102.4, 153.6)_Fare', ('1st', 'S'), 14),
#  ('1st', ('[102.4, 153.6)_Fare',), 31),
#  ('[102.4, 153.6)_Fare', ('1st',), 31),
#  ('[102.4, 153.6)_Fare', ('female', 'Survived', '1_Family'), 8),
#  ('Survived', ('[102.4, 153.6)_Fare', 'female'), 18),
#  ('female', ('[102.4, 153.6)_Fare', 'Survived'), 18),
#  ('[102.4, 153.6)_Fare', ('female', 'Survived'), 18),
#  ('[102.4, 153.6)_Fare', ('female', '1_Family'), 8),
#  ('female', ('[102.4, 153.6)_Fare',), 20),
#  ('[102.4, 153.6)_Fare', ('female',), 20),
#  ('Survived', ('[102.4, 153.6)_Fare',), 23),
#  ('[102.4, 153.6)_Fare', ('Survived',), 23),
#  ('[8.0, 16.0)_Age', ('3_Family', 'Survived', 'male'), 3),
#  ('[8.0, 16.0)_Age', ('3_Family', 'Survived', 'S', '[0.0, 51.2)_Fare'), 4),
#  ('[8.0, 16.0)_Age', ('3_Family', 'Survived', 'S'), 4),
#  ('[8.0, 16.0)_Age', ('3_Family', 'Survived', '[0.0, 51.2)_Fare'), 4),
#  ('[8.0, 16.0)_Age',
#   ('3_Family', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'),
#   3),
#  ('[8.0, 16.0)_Age', ('3_Family', '3rd', 'Not Survived'), 3),
#  ('[8.0, 16.0)_Age', ('3_Family', '3rd', 'male', '[0.0, 51.2)_Fare'), 3),
#  ('[8.0, 16.0)_Age', ('3_Family', '3rd', 'male'), 3),
#  ('[8.0, 16.0)_Age', ('3_Family', '3rd', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('[8.0, 16.0)_Age', ('3_Family', '3rd', 'S'), 3),
#  ('[8.0, 16.0)_Age', ('3_Family', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('[8.0, 16.0)_Age', ('3_Family', '3rd'), 5),
#  ('[8.0, 16.0)_Age', ('3_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 3),
#  ('[8.0, 16.0)_Age', ('3_Family', 'male', '[0.0, 51.2)_Fare'), 4),
#  ('3_Family', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('[8.0, 16.0)_Age', ('3_Family', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('3_Family', ('[8.0, 16.0)_Age', 'S'), 5),
#  ('3_Family', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 7),
#  ('[8.0, 16.0)_Age', ('3_Family', '[0.0, 51.2)_Fare'), 7),
#  ('3_Family', ('[8.0, 16.0)_Age',), 7),
#  ('[8.0, 16.0)_Age', ('3_Family',), 7),
#  ('[8.0, 16.0)_Age', ('2_Family', 'C', 'female', 'Survived'), 3),
#  ('[8.0, 16.0)_Age', ('2_Family', 'C', 'female'), 4),
#  ('[8.0, 16.0)_Age', ('2_Family', 'C', 'Survived'), 4),
#  ('[8.0, 16.0)_Age', ('2_Family', 'C', '[0.0, 51.2)_Fare'), 5),
#  ('[8.0, 16.0)_Age', ('2_Family', 'C'), 5),
#  ('[8.0, 16.0)_Age',
#   ('2_Family', 'female', 'Survived', '[0.0, 51.2)_Fare'),
#   4),
#  ('[8.0, 16.0)_Age', ('2_Family', 'female', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('[8.0, 16.0)_Age', ('2_Family', 'female', '3rd'), 3),
#  ('[8.0, 16.0)_Age', ('2_Family', 'female', '[0.0, 51.2)_Fare'), 5),
#  ('[8.0, 16.0)_Age', ('2_Family', 'female'), 6),
#  ('[8.0, 16.0)_Age', ('2_Family', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 3),
#  ('[8.0, 16.0)_Age', ('2_Family', 'Survived', '3rd'), 3),
#  ('[8.0, 16.0)_Age', ('2_Family', 'Survived', '[0.0, 51.2)_Fare'), 5),
#  ('[8.0, 16.0)_Age', ('C', 'female', 'Survived', '[0.0, 51.2)_Fare'), 5),
#  ('[8.0, 16.0)_Age', ('C', 'female', 'Survived'), 5),
#  ('[8.0, 16.0)_Age', ('C', 'female', '3rd', '[0.0, 51.2)_Fare'), 6),
#  ('[8.0, 16.0)_Age', ('C', 'female', '3rd'), 6),
#  ('[8.0, 16.0)_Age', ('C', 'female', '[0.0, 51.2)_Fare'), 7),
#  ('C', ('[8.0, 16.0)_Age', 'female'), 7),
#  ('[8.0, 16.0)_Age', ('C', 'female'), 7),
#  ('[8.0, 16.0)_Age', ('C', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 5),
#  ('[8.0, 16.0)_Age', ('C', 'Survived', '3rd'), 5),
#  ('[8.0, 16.0)_Age', ('C', 'Survived', '[0.0, 51.2)_Fare'), 6),
#  ('[8.0, 16.0)_Age', ('C', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 4),
#  ('[8.0, 16.0)_Age', ('C', '3rd', 'Not Survived'), 4),
#  ('C', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 9),
#  ('[8.0, 16.0)_Age', ('C', '3rd', '[0.0, 51.2)_Fare'), 9),
#  ('C', ('[8.0, 16.0)_Age', '3rd'), 9),
#  ('[8.0, 16.0)_Age', ('C', '3rd'), 9),
#  ('C', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 10),
#  ('[8.0, 16.0)_Age', ('C', '[0.0, 51.2)_Fare'), 10),
#  ('C', ('[8.0, 16.0)_Age',), 10),
#  ('[8.0, 16.0)_Age', ('C',), 10),
#  ('[8.0, 16.0)_Age',
#   ('female', '3rd', 'Not Survived', 'S', '[0.0, 51.2)_Fare'),
#   7),
#  ('[8.0, 16.0)_Age', ('female', '3rd', 'Not Survived', 'S'), 7),
#  ('[8.0, 16.0)_Age', ('female', '3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 9),
#  ('[8.0, 16.0)_Age', ('female', '3rd', 'Not Survived'), 9),
#  ('[8.0, 16.0)_Age', ('female', '3rd', 'S', '[0.0, 51.2)_Fare'), 7),
#  ('[8.0, 16.0)_Age', ('female', '3rd', 'S'), 7),
#  ('female', ('[8.0, 16.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 14),
#  ('[8.0, 16.0)_Age', ('female', '3rd', '[0.0, 51.2)_Fare'), 14),
#  ('3rd', ('[8.0, 16.0)_Age', 'female'), 14),
#  ('female', ('[8.0, 16.0)_Age', '3rd'), 14),
#  ('[8.0, 16.0)_Age', ('female', '3rd'), 14),
#  ('[8.0, 16.0)_Age', ('female', 'Not Survived', 'S', '[0.0, 51.2)_Fare'), 7),
#  ('[8.0, 16.0)_Age', ('female', 'Not Survived', 'S'), 7),
#  ('[8.0, 16.0)_Age', ('female', 'Not Survived', '[0.0, 51.2)_Fare'), 9),
#  ('[8.0, 16.0)_Age', ('female', 'Not Survived'), 9),
#  ('female', ('[8.0, 16.0)_Age', 'S'), 11),
#  ('female', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 17),
#  ('[8.0, 16.0)_Age', ('female', '[0.0, 51.2)_Fare'), 17),
#  ('female', ('[8.0, 16.0)_Age',), 19),
#  ('[8.0, 16.0)_Age', ('female',), 19),
#  ('[8.0, 16.0)_Age', ('Survived', '3rd', '[0.0, 51.2)_Fare'), 8),
#  ('[8.0, 16.0)_Age', ('Survived', '3rd'), 8),
#  ('[0.0, 51.2)_Fare', ('[8.0, 16.0)_Age', '3rd', 'Not Survived'), 18),
#  ('3rd', ('[8.0, 16.0)_Age', 'Not Survived', '[0.0, 51.2)_Fare'), 18),
#  ('[8.0, 16.0)_Age', ('3rd', 'Not Survived', '[0.0, 51.2)_Fare'), 18),
#  ('3rd', ('[8.0, 16.0)_Age', 'Not Survived'), 18),
#  ('[8.0, 16.0)_Age', ('3rd', 'Not Survived'), 18),
#  ('3rd', ('[8.0, 16.0)_Age', 'S', '[0.0, 51.2)_Fare'), 15),
#  ('3rd', ('[8.0, 16.0)_Age', 'S'), 15),
#  ('[0.0, 51.2)_Fare', ('[8.0, 16.0)_Age', '3rd'), 26),
#  ('3rd', ('[8.0, 16.0)_Age', '[0.0, 51.2)_Fare'), 26),
#  ('[8.0, 16.0)_Age', ('3rd', '[0.0, 51.2)_Fare'), 26),
#  ('3rd', ('[8.0, 16.0)_Age',), 26),
#  ('[8.0, 16.0)_Age', ('3rd',), 26),
#  ('[0.0, 51.2)_Fare', ('[8.0, 16.0)_Age', 'Not Survived'), 18),
#  ('[0.0, 8.0)_Age',
#   ('3_Family', '2nd', 'Survived', 'S', '[0.0, 51.2)_Fare'),
#   9),
#  ('[0.0, 8.0)_Age', ('3_Family', '2nd', 'Survived', 'S'), 9),
#  ('[0.0, 8.0)_Age', ('3_Family', '2nd', 'Survived', '[0.0, 51.2)_Fare'), 10),
#  ('[0.0, 8.0)_Age', ('3_Family', '2nd', 'Survived'), 10),
#  ('[0.0, 8.0)_Age', ('3_Family', '2nd', 'S', '[0.0, 51.2)_Fare'), 9),
#  ('[0.0, 8.0)_Age', ('3_Family', '2nd', 'S'), 9),
#  ('[0.0, 8.0)_Age', ('3_Family', '2nd', '[0.0, 51.2)_Fare'), 10),
#  ('[0.0, 8.0)_Age', ('3_Family', '2nd'), 10),
#  ('[0.0, 8.0)_Age',
#   ('3_Family', 'female', 'Survived', 'S', '[0.0, 51.2)_Fare'),
#   6),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', 'Survived', 'S'), 6),
#  ('3_Family', ('[0.0, 8.0)_Age', 'female', 'Survived', '[0.0, 51.2)_Fare'), 7),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', 'Survived', '[0.0, 51.2)_Fare'), 7),
#  ('3_Family', ('[0.0, 8.0)_Age', 'female', 'Survived'), 7),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', 'Survived'), 7),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', '3rd', '[0.0, 51.2)_Fare'), 4),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', '3rd'), 4),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', 'S', '[0.0, 51.2)_Fare'), 6),
#  ('3_Family', ('[0.0, 8.0)_Age', 'female', 'S'), 6),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', 'S'), 6),
#  ('3_Family', ('[0.0, 8.0)_Age', 'female', '[0.0, 51.2)_Fare'), 7),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female', '[0.0, 51.2)_Fare'), 7),
#  ('3_Family', ('[0.0, 8.0)_Age', 'female'), 7),
#  ('[0.0, 8.0)_Age', ('3_Family', 'female'), 7),
#  ('[0.0, 8.0)_Age', ('3_Family', 'Survived', '3rd', '[0.0, 51.2)_Fare'), 6),
#  ('[0.0, 8.0)_Age', ('3_Family', 'Survived', '3rd'), 6),
#  ('[0.0, 8.0)_Age', ('3_Family', 'Survived', 'male'), 10),
#  ('3_Family', ('[0.0, 8.0)_Age', 'Survived', 'S', '[0.0, 51.2)_Fare'), 14),
#  ('[0.0, 8.0)_Age', ('3_Family', 'Survived', 'S', '[0.0, 51.2)_Fare'), 14),
#  ('3_Family', ('[0.0, 8.0)_Age', 'Survived', 'S'), 15),
#  ('[0.0, 8.0)_Age', ('3_Family', 'Survived', 'S'), 15),
#  ('3_Family', ('[0.0, 8.0)_Age', 'Survived', '[0.0, 51.2)_Fare'), 16),
#  ('[0.0, 8.0)_Age', ('3_Family', 'Survived', '[0.0, 51.2)_Fare'), 16),
#  ('3_Family', ('[0.0, 8.0)_Age', 'Survived'), 17),
#  ('[0.0, 8.0)_Age', ('3_Family', 'Survived'), 17),
#  ('[0.0, 8.0)_Age', ('3_Family', '3rd', 'S', '[0.0, 51.2)_Fare'), 5),
#  ('[0.0, 8.0)_Age', ('3_Family', '3rd', 'S'), 5),
#  ('[0.0, 8.0)_Age', ('3_Family', '3rd', '[0.0, 51.2)_Fare'), 6),
#  ('[0.0, 8.0)_Age', ('3_Family', '3rd'), 6),
#  ('3_Family', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 8),
#  ...]

# %%
for r in rules:
    if r[0] == 'Survived':
        print(r)
# Out:
# ('Survived', ('4_Family', 'female'), 16)
# ('Survived', ('4_Family', 'S'), 15)
# ('Survived', ('4_Family', '[0.0, 51.2)_Fare'), 14)
# ('Survived', ('4_Family',), 21)
# ('Survived', ('[102.4, 153.6)_Fare', '1st', 'female'), 18)
# ('Survived', ('[102.4, 153.6)_Fare', '1st'), 23)
# ('Survived', ('[102.4, 153.6)_Fare', 'female'), 18)
# ('Survived', ('[102.4, 153.6)_Fare',), 23)
# ('Survived', ('[0.0, 8.0)_Age', 'female', 'S'), 12)
# ('Survived', ('[0.0, 8.0)_Age', 'female', '[0.0, 51.2)_Fare'), 18)
# ('Survived', ('[0.0, 8.0)_Age', 'female'), 18)
# ('Survived', ('[0.0, 8.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 17)
# ('Survived', ('[0.0, 8.0)_Age', '3rd'), 17)
# ('Survived', ('[0.0, 8.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 12)
# ('Survived', ('[0.0, 8.0)_Age', 'male', 'S'), 14)
# ('Survived', ('[0.0, 8.0)_Age', 'male', '[0.0, 51.2)_Fare'), 14)
# ('Survived', ('[0.0, 8.0)_Age', 'male'), 16)
# ('Survived', ('[0.0, 8.0)_Age', 'S', '[0.0, 51.2)_Fare'), 24)
# ('Survived', ('[0.0, 8.0)_Age', 'S'), 26)
# ('Survived', ('[0.0, 8.0)_Age', '[0.0, 51.2)_Fare'), 32)
# ('Survived', ('[0.0, 8.0)_Age',), 34)
# ('Survived', ('[48.0, 56.0)_Age', '1st'), 19)
# ('Survived', ('[48.0, 56.0)_Age', 'female'), 17)
# ('Survived', ('[48.0, 56.0)_Age',), 25)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female', '3rd', '1_Family'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female', '3rd', '[0.0, 51.2)_Fare'), 23)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female', '3rd'), 23)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female', '1_Family', '[0.0, 51.2)_Fare'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female', '1_Family'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female', '[0.0, 51.2)_Fare'), 23)
# ('Survived', ('Q', '[16.0, 24.0)_Age', 'female'), 23)
# ('Survived', ('Q', '[16.0, 24.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', '3rd', '1_Family'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 23)
# ('Survived', ('Q', '[16.0, 24.0)_Age', '3rd'), 23)
# ('Survived', ('Q', '[16.0, 24.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', '1_Family'), 18)
# ('Survived', ('Q', '[16.0, 24.0)_Age', '[0.0, 51.2)_Fare'), 23)
# ('Survived', ('Q', '[16.0, 24.0)_Age'), 23)
# ('Survived', ('Q', 'female', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 19)
# ('Survived', ('Q', 'female', '3rd', '1_Family'), 19)
# ('Survived', ('Q', 'female', '3rd', '[0.0, 51.2)_Fare'), 24)
# ('Survived', ('Q', 'female', '3rd'), 24)
# ('Survived', ('Q', 'female', '1_Family', '[0.0, 51.2)_Fare'), 21)
# ('Survived', ('Q', 'female', '1_Family'), 21)
# ('Survived', ('Q', 'female', '[0.0, 51.2)_Fare'), 26)
# ('Survived', ('Q', 'female'), 27)
# ('Survived', ('[40.0, 48.0)_Age', 'female', 'S'), 12)
# ('Survived', ('[40.0, 48.0)_Age', 'female'), 17)
# ('Survived', ('3_Family', 'C'), 14)
# ('Survived', ('3_Family', '2nd', 'S', '[0.0, 51.2)_Fare'), 20)
# ('Survived', ('3_Family', '2nd', 'S'), 20)
# ('Survived', ('3_Family', '2nd', '[0.0, 51.2)_Fare'), 21)
# ('Survived', ('3_Family', '2nd'), 21)
# ('Survived', ('3_Family', '1st'), 18)
# ('Survived', ('3_Family', 'female', '3rd', '[0.0, 51.2)_Fare'), 12)
# ('Survived', ('3_Family', 'female', '3rd'), 12)
# ('Survived', ('3_Family', 'female', 'S', '[0.0, 51.2)_Fare'), 22)
# ('Survived', ('3_Family', 'female', 'S'), 29)
# ('Survived', ('3_Family', 'female', '[0.0, 51.2)_Fare'), 28)
# ('Survived', ('3_Family', 'female'), 38)
# ('Survived', ('3_Family', 'S', '[0.0, 51.2)_Fare'), 33)
# ('Survived', ('3_Family', 'S'), 43)
# ('Survived', ('3_Family', '[0.0, 51.2)_Fare'), 44)
# ('Survived', ('3_Family',), 59)
# ('Survived', ('[51.2, 102.4)_Fare', '[32.0, 40.0)_Age', '1st', 'female'), 19)
# ('Survived', ('[51.2, 102.4)_Fare', '[32.0, 40.0)_Age', '1st'), 21)
# ('Survived', ('[51.2, 102.4)_Fare', '[32.0, 40.0)_Age', 'female'), 19)
# ('Survived', ('[51.2, 102.4)_Fare', '[32.0, 40.0)_Age', 'S'), 16)
# ('Survived', ('[51.2, 102.4)_Fare', '[32.0, 40.0)_Age'), 23)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family', 'C', '1st'), 18)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family', 'C'), 18)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family', '1st', 'female'), 26)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family', '1st', 'S'), 18)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family', '1st'), 37)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family', 'female'), 26)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family', 'S'), 18)
# ('Survived', ('[51.2, 102.4)_Fare', '2_Family'), 37)
# ('Survived', ('[51.2, 102.4)_Fare', 'C', '1st', 'female'), 19)
# ('Survived', ('[51.2, 102.4)_Fare', 'C', '1st'), 27)
# ('Survived', ('[51.2, 102.4)_Fare', 'C', 'female'), 19)
# ('Survived', ('[51.2, 102.4)_Fare', 'C'), 27)
# ('Survived', ('[51.2, 102.4)_Fare', '1st', 'female', 'S'), 26)
# ('Survived', ('[51.2, 102.4)_Fare', '1st', 'female'), 46)
# ('Survived', ('[51.2, 102.4)_Fare', '1st', '1_Family'), 15)
# ('Survived', ('[51.2, 102.4)_Fare', '1st', 'S'), 33)
# ('Survived', ('[51.2, 102.4)_Fare', '1st'), 61)
# ('Survived', ('[51.2, 102.4)_Fare', '[24.0, 32.0)_Age'), 16)
# ('Survived', ('[51.2, 102.4)_Fare', 'female', 'S'), 28)
# ('Survived', ('[51.2, 102.4)_Fare', 'female'), 48)
# ('Survived', ('[51.2, 102.4)_Fare', '1_Family', 'S'), 13)
# ('Survived', ('[51.2, 102.4)_Fare', '1_Family'), 20)
# ('Survived', ('[51.2, 102.4)_Fare', 'S'), 40)
# ('Survived', ('[51.2, 102.4)_Fare',), 68)
# ('Survived', ('[32.0, 40.0)_Age', '2_Family', '1st'), 17)
# ('Survived', ('[32.0, 40.0)_Age', '2_Family', 'female'), 18)
# ('Survived', ('[32.0, 40.0)_Age', '2_Family', 'S'), 15)
# ('Survived', ('[32.0, 40.0)_Age', '2_Family'), 21)
# ('Survived', ('[32.0, 40.0)_Age', 'C', '1st'), 16)
# ('Survived', ('[32.0, 40.0)_Age', 'C'), 16)
# ('Survived', ('[32.0, 40.0)_Age', '1st', 'female'), 29)
# ('Survived', ('[32.0, 40.0)_Age', '1st', '1_Family'), 16)
# ('Survived', ('[32.0, 40.0)_Age', '1st', 'male'), 11)
# ('Survived', ('[32.0, 40.0)_Age', '1st', 'S'), 23)
# ('Survived', ('[32.0, 40.0)_Age', '1st'), 40)
# ('Survived', ('[32.0, 40.0)_Age', 'female', '1_Family'), 16)
# ('Survived', ('[32.0, 40.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 17)
# ('Survived', ('[32.0, 40.0)_Age', 'female', 'S'), 32)
# ('Survived', ('[32.0, 40.0)_Age', 'female', '[0.0, 51.2)_Fare'), 17)
# ('Survived', ('[32.0, 40.0)_Age', 'female'), 45)
# ('Survived', ('[32.0, 40.0)_Age', 'S'), 47)
# ('Survived', ('[32.0, 40.0)_Age',), 64)
# ('Survived', ('2_Family', 'C', '1st', 'female'), 19)
# ('Survived', ('2_Family', 'C', '1st'), 26)
# ('Survived', ('2_Family', 'C', 'female'), 25)
# ('Survived', ('2_Family', 'C'), 34)
# ('Survived', ('2_Family', '2nd', 'female', '[0.0, 51.2)_Fare'), 17)
# ('Survived', ('2_Family', '2nd', 'female'), 17)
# ('Survived', ('2_Family', '2nd', 'S', '[0.0, 51.2)_Fare'), 15)
# ('Survived', ('2_Family', '2nd', 'S'), 15)
# ('Survived', ('2_Family', '2nd', '[0.0, 51.2)_Fare'), 18)
# ('Survived', ('2_Family', '2nd'), 18)
# ('Survived', ('2_Family', '[16.0, 24.0)_Age', 'female'), 19)
# ('Survived', ('2_Family', '[16.0, 24.0)_Age', 'S'), 11)
# ('Survived', ('2_Family', '[16.0, 24.0)_Age', '[0.0, 51.2)_Fare'), 12)
# ('Survived', ('2_Family', '[16.0, 24.0)_Age'), 21)
# ('Survived', ('2_Family', '1st', 'female', 'S'), 19)
# ('Survived', ('2_Family', '1st', 'female'), 39)
# ('Survived', ('2_Family', '1st', 'S'), 24)
# ('Survived', ('2_Family', '1st'), 51)
# ('Survived', ('2_Family', 'female', '3rd', '[0.0, 51.2)_Fare'), 15)
# ('Survived', ('2_Family', 'female', '3rd'), 15)
# ('Survived', ('2_Family', 'female', 'S', '[0.0, 51.2)_Fare'), 24)
# ('Survived', ('2_Family', 'female', 'S'), 41)
# ('Survived', ('2_Family', 'female', '[0.0, 51.2)_Fare'), 35)
# ('Survived', ('2_Family', 'female'), 71)
# ('Survived', ('2_Family', 'S'), 50)
# ('Survived', ('2_Family',), 89)
# ('Survived', ('C', '[16.0, 24.0)_Age', 'female'), 15)
# ('Survived', ('C', '[16.0, 24.0)_Age'), 20)
# ('Survived', ('C', '1st', 'female', '1_Family'), 17)
# ('Survived', ('C', '1st', 'female'), 42)
# ('Survived', ('C', '1st', '1_Family'), 25)
# ('Survived', ('C', '1st'), 59)
# ('Survived', ('C', 'female', '3rd', '[0.0, 51.2)_Fare'), 15)
# ('Survived', ('C', 'female', '3rd'), 15)
# ('Survived', ('C', 'female', '1_Family'), 23)
# ('Survived', ('C', 'female', '[0.0, 51.2)_Fare'), 27)
# ('Survived', ('C', 'female'), 64)
# ('Survived', ('C',), 93)
# ('Survived', ('2nd', '[24.0, 32.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 19)
# ('Survived', ('2nd', '[24.0, 32.0)_Age', 'female', 'S'), 20)
# ('Survived', ('2nd', '[24.0, 32.0)_Age', 'female', '[0.0, 51.2)_Fare'), 23)
# ('Survived', ('2nd', '[24.0, 32.0)_Age', 'female'), 24)
# ('Survived', ('2nd', 'female', '1_Family', 'S', '[0.0, 51.2)_Fare'), 25)
# ('Survived', ('2nd', 'female', '1_Family', 'S'), 25)
# ('Survived', ('2nd', 'female', '1_Family', '[0.0, 51.2)_Fare'), 29)
# ('Survived', ('2nd', 'female', '1_Family'), 29)
# ('Survived', ('2nd', 'female', 'S', '[0.0, 51.2)_Fare'), 59)
# ('Survived', ('2nd', 'female', 'S'), 61)
# ('Survived', ('2nd', 'female', '[0.0, 51.2)_Fare'), 68)
# ('Survived', ('2nd', 'female'), 70)
# ('Survived', ('2nd', 'S', '[0.0, 51.2)_Fare'), 74)
# ('Survived', ('2nd', 'S'), 76)
# ('Survived', ('2nd', '[0.0, 51.2)_Fare'), 85)
# ('Survived', ('2nd',), 87)
# ('Survived', ('[16.0, 24.0)_Age', '1st', 'female'), 19)
# ('Survived', ('[16.0, 24.0)_Age', '1st'), 21)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 27)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '3rd', '1_Family'), 27)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '3rd', '[0.0, 51.2)_Fare'), 39)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '3rd'), 39)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '1_Family', 'S', '[0.0, 51.2)_Fare'), 11)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '1_Family', 'S'), 14)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '1_Family', '[0.0, 51.2)_Fare'), 33)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '1_Family'), 36)
# ('Survived', ('[16.0, 24.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 22)
# ('Survived', ('[16.0, 24.0)_Age', 'female', 'S'), 30)
# ('Survived', ('[16.0, 24.0)_Age', 'female', '[0.0, 51.2)_Fare'), 53)
# ('Survived', ('[16.0, 24.0)_Age', 'female'), 68)
# ('Survived', ('1st', '[24.0, 32.0)_Age', '1_Family'), 16)
# ('Survived', ('1st', '[24.0, 32.0)_Age'), 23)
# ('Survived', ('1st', 'female', '1_Family'), 33)
# ('Survived', ('1st', 'female', 'S'), 48)
# ('Survived', ('1st', 'female'), 91)
# ('Survived', ('1st', '1_Family', 'S'), 33)
# ('Survived', ('1st', '1_Family'), 58)
# ('Survived', ('1st', 'S'), 76)
# ('Survived', ('1st',), 136)
# ('Survived', ('[24.0, 32.0)_Age', 'female', '1_Family', 'S', '[0.0, 51.2)_Fare'), 13)
# ('Survived', ('[24.0, 32.0)_Age', 'female', '1_Family', 'S'), 17)
# ('Survived', ('[24.0, 32.0)_Age', 'female', '1_Family', '[0.0, 51.2)_Fare'), 17)
# ('Survived', ('[24.0, 32.0)_Age', 'female', '1_Family'), 26)
# ('Survived', ('[24.0, 32.0)_Age', 'female', 'S', '[0.0, 51.2)_Fare'), 29)
# ('Survived', ('[24.0, 32.0)_Age', 'female', 'S'), 36)
# ('Survived', ('[24.0, 32.0)_Age', 'female', '[0.0, 51.2)_Fare'), 37)
# ('Survived', ('[24.0, 32.0)_Age', 'female'), 50)
# ('Survived', ('female', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 37)
# ('Survived', ('female', '3rd', '1_Family'), 37)
# ('Survived', ('female', '3rd', '[0.0, 51.2)_Fare'), 72)
# ('Survived', ('female', '3rd'), 72)
# ('Survived', ('female', '1_Family', 'S', '[0.0, 51.2)_Fare'), 43)
# ('Survived', ('female', '1_Family', 'S'), 55)
# ('Survived', ('female', '1_Family', '[0.0, 51.2)_Fare'), 73)
# ('Survived', ('female', '1_Family'), 99)
# ('Survived', ('female', 'S', '[0.0, 51.2)_Fare'), 100)
# ('Survived', ('female', 'S'), 142)
# ('Survived', ('female', '[0.0, 51.2)_Fare'), 153)
# ('Survived', ('female',), 233)

# %%
for r in rules:
    if r[0] == 'Not Survived':
        print(r)
# Out:
# ('Not Survived', ('6_Family', '[0.0, 51.2)_Fare'), 17)
# ('Not Survived', ('6_Family',), 19)
# ('Not Survived', ('[48.0, 56.0)_Age', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 16)
# ('Not Survived', ('[48.0, 56.0)_Age', '1_Family', 'male', 'S'), 16)
# ('Not Survived', ('[48.0, 56.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 16)
# ('Not Survived', ('[48.0, 56.0)_Age', '1_Family', 'male'), 16)
# ('Not Survived', ('[48.0, 56.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 17)
# ('Not Survived', ('[48.0, 56.0)_Age', 'male', 'S'), 20)
# ('Not Survived', ('[48.0, 56.0)_Age', 'male', '[0.0, 51.2)_Fare'), 17)
# ('Not Survived', ('[48.0, 56.0)_Age', 'male'), 23)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 21)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd', '1_Family', 'male'), 21)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 22)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd', '1_Family'), 22)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 25)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd', 'male'), 25)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 26)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '3rd'), 26)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 21)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '1_Family', 'male'), 21)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 22)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '1_Family'), 22)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', 'male', '[0.0, 51.2)_Fare'), 25)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', 'male'), 25)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age', '[0.0, 51.2)_Fare'), 26)
# ('Not Survived', ('Q', '[24.0, 32.0)_Age'), 26)
# ('Not Survived', ('Q', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 27)
# ('Not Survived', ('Q', '3rd', '1_Family', 'male'), 27)
# ('Not Survived', ('Q', '3rd', 'male', '[0.0, 51.2)_Fare'), 36)
# ('Not Survived', ('Q', '3rd', 'male'), 36)
# ('Not Survived', ('Q', '1_Family', 'male', '[0.0, 51.2)_Fare'), 28)
# ('Not Survived', ('Q', '1_Family', 'male'), 28)
# ('Not Survived', ('Q', 'male', '[0.0, 51.2)_Fare'), 37)
# ('Not Survived', ('Q', 'male'), 38)
# ('Not Survived', ('[40.0, 48.0)_Age', '1st', '1_Family', 'male', 'S'), 19)
# ('Not Survived', ('[40.0, 48.0)_Age', '1st', '1_Family', 'male'), 26)
# ('Not Survived', ('[40.0, 48.0)_Age', '1st', 'male', 'S'), 22)
# ('Not Survived', ('[40.0, 48.0)_Age', '1st', 'male'), 30)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 16)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', '1_Family'), 16)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 17)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', 'male', 'S'), 17)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 21)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', 'male'), 21)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 24)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', 'S'), 24)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 29)
# ('Not Survived', ('[40.0, 48.0)_Age', '3rd'), 29)
# ('Not Survived', ('[40.0, 48.0)_Age', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 31)
# ('Not Survived', ('[40.0, 48.0)_Age', '1_Family', 'male', 'S'), 34)
# ('Not Survived', ('[40.0, 48.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 39)
# ('Not Survived', ('[40.0, 48.0)_Age', '1_Family', 'male'), 44)
# ('Not Survived', ('[40.0, 48.0)_Age', '1_Family', 'S'), 35)
# ('Not Survived', ('[40.0, 48.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 40)
# ('Not Survived', ('[40.0, 48.0)_Age', '1_Family'), 45)
# ('Not Survived', ('[40.0, 48.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 39)
# ('Not Survived', ('[40.0, 48.0)_Age', 'male', 'S'), 45)
# ('Not Survived', ('[40.0, 48.0)_Age', 'male', '[0.0, 51.2)_Fare'), 48)
# ('Not Survived', ('[40.0, 48.0)_Age', 'male'), 57)
# ('Not Survived', ('[40.0, 48.0)_Age', 'S', '[0.0, 51.2)_Fare'), 47)
# ('Not Survived', ('[40.0, 48.0)_Age', 'S'), 53)
# ('Not Survived', ('[40.0, 48.0)_Age', '[0.0, 51.2)_Fare'), 57)
# ('Not Survived', ('[40.0, 48.0)_Age',), 66)
# ('Not Survived', ('[32.0, 40.0)_Age', '2nd', 'male', 'S', '[0.0, 51.2)_Fare'), 17)
# ('Not Survived', ('[32.0, 40.0)_Age', '2nd', 'male', 'S'), 18)
# ('Not Survived', ('[32.0, 40.0)_Age', '2nd', 'male', '[0.0, 51.2)_Fare'), 19)
# ('Not Survived', ('[32.0, 40.0)_Age', '2nd', 'male'), 20)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 23)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family', 'male', 'S'), 23)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 28)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family', 'male'), 28)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 24)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family', 'S'), 24)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 29)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '1_Family'), 29)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 30)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', 'male', 'S'), 30)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 35)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', 'male'), 35)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 32)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', 'S'), 32)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 39)
# ('Not Survived', ('[32.0, 40.0)_Age', '3rd'), 39)
# ('Not Survived', ('[32.0, 40.0)_Age', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 37)
# ('Not Survived', ('[32.0, 40.0)_Age', '1_Family', 'male', 'S'), 37)
# ('Not Survived', ('[32.0, 40.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 44)
# ('Not Survived', ('[32.0, 40.0)_Age', '1_Family', 'male'), 44)
# ('Not Survived', ('[32.0, 40.0)_Age', '1_Family', 'S', '[0.0, 51.2)_Fare'), 39)
# ('Not Survived', ('[32.0, 40.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 46)
# ('Not Survived', ('[32.0, 40.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 50)
# ('Not Survived', ('[32.0, 40.0)_Age', 'male', 'S'), 54)
# ('Not Survived', ('[32.0, 40.0)_Age', 'male', '[0.0, 51.2)_Fare'), 59)
# ('Not Survived', ('[32.0, 40.0)_Age', 'male'), 63)
# ('Not Survived', ('[32.0, 40.0)_Age', '[0.0, 51.2)_Fare'), 64)
# ('Not Survived', ('2_Family', '[24.0, 32.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 19)
# ('Not Survived', ('2_Family', '[24.0, 32.0)_Age', '3rd'), 19)
# ('Not Survived', ('2_Family', '[24.0, 32.0)_Age', 'male', 'S'), 15)
# ('Not Survived', ('2_Family', '[24.0, 32.0)_Age', 'male', '[0.0, 51.2)_Fare'), 21)
# ('Not Survived', ('2_Family', '[24.0, 32.0)_Age', 'male'), 25)
# ('Not Survived', ('2_Family', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 17)
# ('Not Survived', ('2_Family', '3rd', 'male', 'S'), 17)
# ('Not Survived', ('2_Family', '3rd', 'male', '[0.0, 51.2)_Fare'), 23)
# ('Not Survived', ('2_Family', '3rd', 'male'), 23)
# ('Not Survived', ('2_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 28)
# ('Not Survived', ('2_Family', 'male', 'S'), 40)
# ('Not Survived', ('2_Family', 'male', '[0.0, 51.2)_Fare'), 38)
# ('Not Survived', ('2_Family', 'male'), 56)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 18)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd', '1_Family', 'male'), 18)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 18)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd', '1_Family'), 18)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 21)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd', 'male'), 21)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 21)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '3rd'), 21)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 20)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', '1_Family', 'male'), 21)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', 'male', '[0.0, 51.2)_Fare'), 27)
# ('Not Survived', ('C', '[24.0, 32.0)_Age', 'male'), 31)
# ('Not Survived', ('C', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 28)
# ('Not Survived', ('C', '3rd', '1_Family', 'male'), 28)
# ('Not Survived', ('C', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 29)
# ('Not Survived', ('C', '3rd', '1_Family'), 29)
# ('Not Survived', ('C', '3rd', 'male', '[0.0, 51.2)_Fare'), 33)
# ('Not Survived', ('C', '3rd', 'male'), 33)
# ('Not Survived', ('C', '1_Family', 'male', '[0.0, 51.2)_Fare'), 42)
# ('Not Survived', ('C', '1_Family', 'male'), 46)
# ('Not Survived', ('C', 'male', '[0.0, 51.2)_Fare'), 53)
# ('Not Survived', ('C', 'male'), 66)
# ('Not Survived', ('2nd', '[16.0, 24.0)_Age', 'male', 'S'), 17)
# ('Not Survived', ('2nd', '[16.0, 24.0)_Age', 'male'), 18)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 24)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', '1_Family', 'male', 'S'), 24)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 25)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', '1_Family', 'male'), 25)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 28)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', 'male', 'S'), 29)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', 'male', '[0.0, 51.2)_Fare'), 33)
# ('Not Survived', ('2nd', '[24.0, 32.0)_Age', 'male'), 34)
# ('Not Survived', ('2nd', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 59)
# ('Not Survived', ('2nd', '1_Family', 'male', 'S'), 61)
# ('Not Survived', ('2nd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 63)
# ('Not Survived', ('2nd', '1_Family', 'male'), 65)
# ('Not Survived', ('2nd', 'male', 'S', '[0.0, 51.2)_Fare'), 77)
# ('Not Survived', ('2nd', 'male', 'S'), 82)
# ('Not Survived', ('2nd', 'male', '[0.0, 51.2)_Fare'), 86)
# ('Not Survived', ('2nd', 'male'), 91)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 57)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', 'male', 'S'), 57)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 62)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', 'male'), 62)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 65)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', 'S'), 65)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 76)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '1_Family'), 76)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 66)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'male', 'S'), 66)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 72)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'male'), 72)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 84)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', 'S'), 87)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 101)
# ('Not Survived', ('[16.0, 24.0)_Age', '3rd'), 104)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 68)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'male', 'S'), 70)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 74)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'male'), 77)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'S', '[0.0, 51.2)_Fare'), 76)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', 'S'), 78)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 88)
# ('Not Survived', ('[16.0, 24.0)_Age', '1_Family'), 91)
# ('Not Survived', ('[16.0, 24.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 80)
# ('Not Survived', ('[16.0, 24.0)_Age', 'male', 'S'), 86)
# ('Not Survived', ('[16.0, 24.0)_Age', 'male', '[0.0, 51.2)_Fare'), 87)
# ('Not Survived', ('[16.0, 24.0)_Age', 'male'), 95)
# ('Not Survived', ('[16.0, 24.0)_Age', 'S', '[0.0, 51.2)_Fare'), 98)
# ('Not Survived', ('[16.0, 24.0)_Age', 'S'), 107)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 73)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'male', 'S'), 75)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 112)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'male'), 114)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 78)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', 'S'), 80)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family', '[0.0, 51.2)_Fare'), 118)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '1_Family'), 120)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 89)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male', 'S'), 95)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male', '[0.0, 51.2)_Fare'), 135)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'male'), 141)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'S', '[0.0, 51.2)_Fare'), 101)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', 'S'), 107)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd', '[0.0, 51.2)_Fare'), 148)
# ('Not Survived', ('[24.0, 32.0)_Age', '3rd'), 154)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 100)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male', 'S'), 102)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male', '[0.0, 51.2)_Fare'), 141)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'male'), 144)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'S', '[0.0, 51.2)_Fare'), 106)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', 'S'), 108)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family', '[0.0, 51.2)_Fare'), 148)
# ('Not Survived', ('[24.0, 32.0)_Age', '1_Family'), 151)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male', 'S', '[0.0, 51.2)_Fare'), 120)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male', 'S'), 129)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male', '[0.0, 51.2)_Fare'), 172)
# ('Not Survived', ('[24.0, 32.0)_Age', 'male'), 185)
# ('Not Survived', ('[24.0, 32.0)_Age', 'S', '[0.0, 51.2)_Fare'), 135)
# ('Not Survived', ('[24.0, 32.0)_Age', 'S'), 145)
# ('Not Survived', ('[24.0, 32.0)_Age', '[0.0, 51.2)_Fare'), 188)
# ('Not Survived', ('[24.0, 32.0)_Age',), 202)
# ('Not Survived', ('3rd', '1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 175)
# ('Not Survived', ('3rd', '1_Family', 'male', 'S'), 177)
# ('Not Survived', ('3rd', '1_Family', 'male', '[0.0, 51.2)_Fare'), 230)
# ('Not Survived', ('3rd', '1_Family', 'male'), 232)
# ('Not Survived', ('3rd', '1_Family', 'S', '[0.0, 51.2)_Fare'), 191)
# ('Not Survived', ('3rd', '1_Family', 'S'), 193)
# ('Not Survived', ('3rd', '1_Family', '[0.0, 51.2)_Fare'), 253)
# ('Not Survived', ('3rd', '1_Family'), 255)
# ('Not Survived', ('3rd', 'male', 'S', '[0.0, 51.2)_Fare'), 225)
# ('Not Survived', ('3rd', 'male', 'S'), 231)
# ('Not Survived', ('3rd', 'male', '[0.0, 51.2)_Fare'), 294)
# ('Not Survived', ('3rd', 'male'), 300)
# ('Not Survived', ('3rd', 'S', '[0.0, 51.2)_Fare'), 277)
# ('Not Survived', ('3rd', 'S'), 286)
# ('Not Survived', ('3rd', '[0.0, 51.2)_Fare'), 363)
# ('Not Survived', ('3rd',), 372)
# ('Not Survived', ('1_Family', 'male', 'S', '[0.0, 51.2)_Fare'), 266)
# ('Not Survived', ('1_Family', 'male', 'S'), 273)
# ('Not Survived', ('1_Family', 'male', '[0.0, 51.2)_Fare'), 336)
# ('Not Survived', ('1_Family', 'male'), 347)
# ('Not Survived', ('1_Family', 'S', '[0.0, 51.2)_Fare'), 285)
# ('Not Survived', ('1_Family', 'S'), 292)
# ('Not Survived', ('1_Family', '[0.0, 51.2)_Fare'), 363)
# ('Not Survived', ('1_Family',), 374)
# ('Not Survived', ('male', 'S', '[0.0, 51.2)_Fare'), 334)
# ('Not Survived', ('male', 'S'), 364)
# ('Not Survived', ('male', '[0.0, 51.2)_Fare'), 424)
# ('Not Survived', ('male',), 468)
# ('Not Survived', ('S', '[0.0, 51.2)_Fare'), 392)
# ('Not Survived', ('S',), 427)
# ('Not Survived', ('[0.0, 51.2)_Fare',), 500)
